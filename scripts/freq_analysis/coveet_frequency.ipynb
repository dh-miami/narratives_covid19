# %% [markdown]
# # digital narratives of COVID-19: frequency analysis
#
# In this notebook we demonstrate how to use *coveet*, a Python script that retrieves basic statistics (most frequent words, bigrams, trigrams, top users, hashtags) from our curated COVID-19 database about our collection. We visualize the results using bar charts to get a sense of top words/bigrams/trigrams/ec. over the span of a week in each geographic area. Please feel free to modify this notebook or, if you would like to preserve this version, make a copy of it by clicking "File" > "Make a Copy..."
#
# To follow along, we recommend running the script portions piecemeal, in order.
#
# __Author:__
#
# * Jerry Bonnell, [j.bonnell@miami.edu](mailto:j.bonnell@miami.edu), University of Miami
#
#
# ## Table of Contents
#
# 0. Setting Up
# 1. Querying the database API
# 2. Tidying up the queried data
# 3. Retrieving top n-grams or hashtags
# 4. Visualization
#     - 4.1. Tabular representation
#     - 4.2. Bar char matrix
# 5. More advanced explorations
#     - 5.1. Unique words by location-language pair mode
#     - 5.2. Unique words by date mode

# %% [markdown]
# ## 0. Setting Up
#
# Before we get started, let's set up the notebook by installing and importing libraries we need. The `requirements.txt` file specifies all the packages to install on your computer for this notebook.

# %%
# !pip3 install -r requirements.txt  # may need to replace "pip3" with "conda"
# Out:
# Requirement already satisfied: appnope==0.1.0 in /home/jbonnell/.pyenv/versions/3.8.3/lib/python3.8/site-packages (from -r requirements.txt (line 1)) (0.1.0)
# Requirement already satisfied: attrs==19.3.0 in /home/jbonnell/.pyenv/versions/3.8.3/lib/python3.8/site-packages (from -r requirements.txt (line 2)) (19.3.0)
# Requirement already satisfied: backcall==0.2.0 in /home/jbonnell/.pyenv/versions/3.8.3/lib/python3.8/site-packages (from -r requirements.txt (line 3)) (0.2.0)
# Requirement already satisfied: bleach==3.1.5 in /home/jbonnell/.pyenv/versions/3.8.3/lib/python3.8/site-packages (from -r requirements.txt (line 4)) (3.1.5)
# Requirement already satisfied: certifi==2020.6.20 in /home/jbonnell/.pyenv/versions/3.8.3/lib/python3.8/site-packages (from -r requirements.txt (line 5)) (2020.6.20)
# Requirement already satisfied: chardet==3.0.4 in /home/jbonnell/.pyenv/versions/3.8.3/lib/python3.8/site-packages (from -r requirements.txt (line 6)) (3.0.4)
# Requirement already satisfied: click==7.1.2 in /home/jbonnell/.pyenv/versions/3.8.3/lib/python3.8/site-packages (from -r requirements.txt (line 7)) (7.1.2)
# Requirement already satisfied: cycler==0.10.0 in /home/jbonnell/.pyenv/versions/3.8.3/lib/python3.8/site-packages (from -r requirements.txt (line 8)) (0.10.0)
# Requirement already satisfied: decorator==4.4.2 in /home/jbonnell/.pyenv/versions/3.8.3/lib/python3.8/site-packages (from -r requirements.txt (line 9)) (4.4.2)
# Requirement already satisfied: defusedxml==0.6.0 in /home/jbonnell/.pyenv/versions/3.8.3/lib/python3.8/site-packages (from -r requirements.txt (line 10)) (0.6.0)
# Requirement already satisfied: entrypoints==0.3 in /home/jbonnell/.pyenv/versions/3.8.3/lib/python3.8/site-packages (from -r requirements.txt (line 11)) (0.3)
# Requirement already satisfied: idna==2.10 in /home/jbonnell/.pyenv/versions/3.8.3/lib/python3.8/site-packages (from -r requirements.txt (line 12)) (2.10)
# Requirement already satisfied: ipykernel==5.3.2 in /home/jbonnell/.pyenv/versions/3.8.3/lib/python3.8/site-packages (from -r requirements.txt (line 13)) (5.3.2)
# Requirement already satisfied: ipython==7.16.1 in /home/jbonnell/.pyenv/versions/3.8.3/lib/python3.8/site-packages (from -r requirements.txt (line 14)) (7.16.1)
# Requirement already satisfied: ipython-genutils==0.2.0 in /home/jbonnell/.pyenv/versions/3.8.3/lib/python3.8/site-packages (from -r requirements.txt (line 15)) (0.2.0)
# Requirement already satisfied: ipywidgets==7.5.1 in /home/jbonnell/.pyenv/versions/3.8.3/lib/python3.8/site-packages (from -r requirements.txt (line 16)) (7.5.1)
# Requirement already satisfied: jedi==0.17.1 in /home/jbonnell/.pyenv/versions/3.8.3/lib/python3.8/site-packages (from -r requirements.txt (line 17)) (0.17.1)
# Requirement already satisfied: Jinja2==2.11.2 in /home/jbonnell/.pyenv/versions/3.8.3/lib/python3.8/site-packages (from -r requirements.txt (line 18)) (2.11.2)
# Requirement already satisfied: joblib==0.16.0 in /home/jbonnell/.pyenv/versions/3.8.3/lib/python3.8/site-packages (from -r requirements.txt (line 19)) (0.16.0)
# Requirement already satisfied: jsonschema==3.2.0 in /home/jbonnell/.pyenv/versions/3.8.3/lib/python3.8/site-packages (from -r requirements.txt (line 20)) (3.2.0)
# Requirement already satisfied: jupyter==1.0.0 in /home/jbonnell/.pyenv/versions/3.8.3/lib/python3.8/site-packages (from -r requirements.txt (line 21)) (1.0.0)
# Requirement already satisfied: jupyter-client==6.1.5 in /home/jbonnell/.pyenv/versions/3.8.3/lib/python3.8/site-packages (from -r requirements.txt (line 22)) (6.1.5)
# Requirement already satisfied: jupyter-console==6.1.0 in /home/jbonnell/.pyenv/versions/3.8.3/lib/python3.8/site-packages (from -r requirements.txt (line 23)) (6.1.0)
# Requirement already satisfied: jupyter-core==4.6.3 in /home/jbonnell/.pyenv/versions/3.8.3/lib/python3.8/site-packages (from -r requirements.txt (line 24)) (4.6.3)
# Requirement already satisfied: kiwisolver==1.2.0 in /home/jbonnell/.pyenv/versions/3.8.3/lib/python3.8/site-packages (from -r requirements.txt (line 25)) (1.2.0)
# Requirement already satisfied: MarkupSafe==1.1.1 in /home/jbonnell/.pyenv/versions/3.8.3/lib/python3.8/site-packages (from -r requirements.txt (line 26)) (1.1.1)
# Requirement already satisfied: matplotlib==3.2.2 in /home/jbonnell/.pyenv/versions/3.8.3/lib/python3.8/site-packages (from -r requirements.txt (line 27)) (3.2.2)
# Requirement already satisfied: mistune==0.8.4 in /home/jbonnell/.pyenv/versions/3.8.3/lib/python3.8/site-packages (from -r requirements.txt (line 28)) (0.8.4)
# Requirement already satisfied: nbconvert==5.6.1 in /home/jbonnell/.pyenv/versions/3.8.3/lib/python3.8/site-packages (from -r requirements.txt (line 29)) (5.6.1)
# Requirement already satisfied: nbformat==5.0.7 in /home/jbonnell/.pyenv/versions/3.8.3/lib/python3.8/site-packages (from -r requirements.txt (line 30)) (5.0.7)
# Requirement already satisfied: nltk==3.5 in /home/jbonnell/.pyenv/versions/3.8.3/lib/python3.8/site-packages (from -r requirements.txt (line 31)) (3.5)
# Requirement already satisfied: notebook==6.0.3 in /home/jbonnell/.pyenv/versions/3.8.3/lib/python3.8/site-packages (from -r requirements.txt (line 32)) (6.0.3)
# Requirement already satisfied: numpy==1.19.0 in /home/jbonnell/.pyenv/versions/3.8.3/lib/python3.8/site-packages (from -r requirements.txt (line 33)) (1.19.0)
# Requirement already satisfied: packaging==20.4 in /home/jbonnell/.pyenv/versions/3.8.3/lib/python3.8/site-packages (from -r requirements.txt (line 34)) (20.4)
# Requirement already satisfied: pandas==1.0.5 in /home/jbonnell/.pyenv/versions/3.8.3/lib/python3.8/site-packages (from -r requirements.txt (line 35)) (1.0.5)
# Requirement already satisfied: pandocfilters==1.4.2 in /home/jbonnell/.pyenv/versions/3.8.3/lib/python3.8/site-packages (from -r requirements.txt (line 36)) (1.4.2)
# Requirement already satisfied: parso==0.7.0 in /home/jbonnell/.pyenv/versions/3.8.3/lib/python3.8/site-packages (from -r requirements.txt (line 37)) (0.7.0)
# Requirement already satisfied: pexpect==4.8.0 in /home/jbonnell/.pyenv/versions/3.8.3/lib/python3.8/site-packages (from -r requirements.txt (line 38)) (4.8.0)
# Requirement already satisfied: pickleshare==0.7.5 in /home/jbonnell/.pyenv/versions/3.8.3/lib/python3.8/site-packages (from -r requirements.txt (line 39)) (0.7.5)
# Requirement already satisfied: plotly==4.8.1 in /home/jbonnell/.pyenv/versions/3.8.3/lib/python3.8/site-packages (from -r requirements.txt (line 40)) (4.8.1)
# Requirement already satisfied: prometheus-client==0.8.0 in /home/jbonnell/.pyenv/versions/3.8.3/lib/python3.8/site-packages (from -r requirements.txt (line 41)) (0.8.0)
# Requirement already satisfied: prompt-toolkit==3.0.5 in /home/jbonnell/.pyenv/versions/3.8.3/lib/python3.8/site-packages (from -r requirements.txt (line 42)) (3.0.5)
# Requirement already satisfied: ptyprocess==0.6.0 in /home/jbonnell/.pyenv/versions/3.8.3/lib/python3.8/site-packages (from -r requirements.txt (line 43)) (0.6.0)
# Requirement already satisfied: Pygments==2.6.1 in /home/jbonnell/.pyenv/versions/3.8.3/lib/python3.8/site-packages (from -r requirements.txt (line 44)) (2.6.1)
# Requirement already satisfied: pyparsing==2.4.7 in /home/jbonnell/.pyenv/versions/3.8.3/lib/python3.8/site-packages (from -r requirements.txt (line 45)) (2.4.7)
# Requirement already satisfied: pyrsistent==0.16.0 in /home/jbonnell/.pyenv/versions/3.8.3/lib/python3.8/site-packages (from -r requirements.txt (line 46)) (0.16.0)
# Requirement already satisfied: python-dateutil==2.8.1 in /home/jbonnell/.pyenv/versions/3.8.3/lib/python3.8/site-packages (from -r requirements.txt (line 47)) (2.8.1)
# Requirement already satisfied: pytz==2020.1 in /home/jbonnell/.pyenv/versions/3.8.3/lib/python3.8/site-packages (from -r requirements.txt (line 48)) (2020.1)
# Requirement already satisfied: pyzmq==19.0.1 in /home/jbonnell/.pyenv/versions/3.8.3/lib/python3.8/site-packages (from -r requirements.txt (line 49)) (19.0.1)
# Requirement already satisfied: qtconsole==4.7.5 in /home/jbonnell/.pyenv/versions/3.8.3/lib/python3.8/site-packages (from -r requirements.txt (line 50)) (4.7.5)
# Requirement already satisfied: QtPy==1.9.0 in /home/jbonnell/.pyenv/versions/3.8.3/lib/python3.8/site-packages (from -r requirements.txt (line 51)) (1.9.0)
# Requirement already satisfied: regex==2020.6.8 in /home/jbonnell/.pyenv/versions/3.8.3/lib/python3.8/site-packages (from -r requirements.txt (line 52)) (2020.6.8)
# Requirement already satisfied: requests==2.24.0 in /home/jbonnell/.pyenv/versions/3.8.3/lib/python3.8/site-packages (from -r requirements.txt (line 53)) (2.24.0)
# Requirement already satisfied: Send2Trash==1.5.0 in /home/jbonnell/.pyenv/versions/3.8.3/lib/python3.8/site-packages (from -r requirements.txt (line 54)) (1.5.0)
# Requirement already satisfied: six==1.15.0 in /home/jbonnell/.pyenv/versions/3.8.3/lib/python3.8/site-packages (from -r requirements.txt (line 55)) (1.15.0)
# Requirement already satisfied: terminado==0.8.3 in /home/jbonnell/.pyenv/versions/3.8.3/lib/python3.8/site-packages (from -r requirements.txt (line 56)) (0.8.3)
# Requirement already satisfied: testpath==0.4.4 in /home/jbonnell/.pyenv/versions/3.8.3/lib/python3.8/site-packages (from -r requirements.txt (line 57)) (0.4.4)
# Requirement already satisfied: tornado==6.0.4 in /home/jbonnell/.pyenv/versions/3.8.3/lib/python3.8/site-packages (from -r requirements.txt (line 58)) (6.0.4)
# Requirement already satisfied: tqdm==4.47.0 in /home/jbonnell/.pyenv/versions/3.8.3/lib/python3.8/site-packages (from -r requirements.txt (line 59)) (4.47.0)
# Requirement already satisfied: traitlets==4.3.3 in /home/jbonnell/.pyenv/versions/3.8.3/lib/python3.8/site-packages (from -r requirements.txt (line 60)) (4.3.3)
# Requirement already satisfied: urllib3==1.25.9 in /home/jbonnell/.pyenv/versions/3.8.3/lib/python3.8/site-packages (from -r requirements.txt (line 61)) (1.25.9)
# Requirement already satisfied: wcwidth==0.2.5 in /home/jbonnell/.pyenv/versions/3.8.3/lib/python3.8/site-packages (from -r requirements.txt (line 62)) (0.2.5)
# Requirement already satisfied: webencodings==0.5.1 in /home/jbonnell/.pyenv/versions/3.8.3/lib/python3.8/site-packages (from -r requirements.txt (line 63)) (0.5.1)
# Requirement already satisfied: widgetsnbextension==3.5.1 in /home/jbonnell/.pyenv/versions/3.8.3/lib/python3.8/site-packages (from -r requirements.txt (line 64)) (3.5.1)
# Requirement already satisfied: setuptools>=18.5 in /home/jbonnell/.pyenv/versions/3.8.3/lib/python3.8/site-packages (from ipython==7.16.1->-r requirements.txt (line 14)) (41.2.0)
# Requirement already satisfied: retrying>=1.3.3 in /home/jbonnell/.pyenv/versions/3.8.3/lib/python3.8/site-packages (from plotly==4.8.1->-r requirements.txt (line 40)) (1.3.3)
# WARNING: You are using pip version 20.2.2; however, version 20.2.3 is available.
# You should consider upgrading via the '/home/jbonnell/.pyenv/versions/3.8.3/bin/python3.8 -m pip install --upgrade pip' command.

# %%
import numpy as np
import pandas as pd
from coveet import count_ngrams, uniq_vocab_by_group
from collections import Counter
from pprint import pprint
import matplotlib.pyplot as plt

pd.set_option('display.max_colwidth', None)
pd.options.mode.chained_assignment = None

# %% [markdown]
# ## 1. Querying the database API

# %% [markdown]
# __NOTE__ Documentation for the coveet tool is available on the [project GitHub](https://github.com/dh-miami/narratives_covid19/tree/master/scripts/freq_analysis).
#
# We first use coveet to query one week of tweets written in each geographic area. All of the geolocated tweets are written in Spanish, with the exception of Florida where both Spanish and English tweets are obtained.

# %%
# !python3 coveet.py query -g fl ar co ec es mx pe -l en es -d 2020-05-08 2020-05-14
# Out:
# Namespace(date=[datetime.datetime(2020, 5, 8, 0, 0), datetime.datetime(2020, 5, 14, 0, 0)], func=<function handle_query at 0x12f09bf80>, geo=['fl', 'ar', 'co', 'ec', 'es', 'mx', 'pe'], lang=['en', 'es'])
# wrote df to dhcovid_2020-5-8_2020-5-14_en_es_ar_co_ec_es_fl_mx_pe.csv 🎉

# %% [markdown]
# The coveet script just wrote the results to a CSV file called `dhcovid_2020-5-8_2020-5-14_en_es_ar_co_ec_es_fl_mx_pe.csv`. Let's load in this CSV using `pandas`.

# %%
df = pd.read_csv('dhcovid_2020-5-8_2020-5-14_en_es_ar_co_ec_es_fl_mx_pe.csv', index_col=0)

# %% [markdown]
# Let's have a look at what this dataframe looks like...

# %%
df
# Out:
#               date lang geo  \
# 0       2020-05-08   es  fl
# 1       2020-05-08   es  fl
# 2       2020-05-08   es  fl
# 3       2020-05-08   es  fl
# 4       2020-05-08   es  fl
# ...            ...  ...  ..
# 224732  2020-05-14   en  fl
# 224733  2020-05-14   en  fl
# 224734  2020-05-14   en  fl
# 224735  2020-05-14   en  fl
# 224736  2020-05-14   en  fl
#
#                                                                                                                                                                                                                                           text  \
# 0                                                                                                                                                                         muere enfermero cubano que atendia pacientes de covid19 en el caribe
# 1                                                                                                                                                 trump desmonta la incursion frustrada del regimen yo no mandaria un grupito sino un ejercito
# 2                                                                                                                                                                               muere niño de 5 años en nueva york por enfermedad vinculada al
# 3                                                                                                                       el corresponsal medico principal de explico cuales son los factores de riesgo mas frecuentes en hombres que en mujeres
# 4                                                                                                                                           puede quedarse con nosotros para siempre la advertencia de un cientifico ruso sobre el coronavirus
# ...                                                                                                                                                                                                                                        ...
# 224732                                                                                                                                                            breaking dr fauci proclaims 8 new covid19 vaccines will be ready in the fall
# 224733             in an sec filing dating back to last week uber disclosed plans to layoff 3700 employees the figure amounts to around 14 percent of the ride hailing giantrsquos total workforce in the document the company states that the
# 224734  join ms focus for a teleconference designed to help you improve your life with ms with expert speaker mitzi williams md and a topic you care about minorities and covid19 to join the teleconference call 7207409380 preregister today
# 224735                                                                                                                                                     emotional roi should be one of your key performance indicators during covid19 video
# 224736                                                                                                                                                                          coronavirus suppression expert recommendations to beat covid19
#
#                                            hashtags
# 0                                               NaN
# 1       #08may #internacionales #cambioweb #covid19
# 2                                            #covid
# 3                             #diariodelcoronavirus
# 4       #08may #internacionales #cambioweb #covid19
# ...                                             ...
# 224732                                          NaN
# 224733                                          NaN
# 224734                                          NaN
# 224735                                          NaN
# 224736                                          NaN
#
# [224737 rows x 5 columns]

# %% [markdown]
# Observe the stopwords present in the tweet text. Let's filter these out, as well as address some other preprocessing concerns in preparation for the visualization task...

# %% [markdown]
# ## 2. Tidying up the queried data

# %% [markdown]
# We will use the *tidy* mode from coveet to tidy up (or preprocess) the data frame we just obtained. At this moment, two preprocessing concerns take center stage: (1) eliminating __stopwords__, and (2) __lemmatization__ in order to group together all inflections of a word into a single item. Let's do each in turn.

# %% [markdown]
# First, we show how to eliminate stopwords from the query CSV file. The CSV file `dhcovid_2020-5-8_2020-5-14_en_es_ar_co_ec_es_fl_mx_pe.csv` is provided as input, and a filtered CSV file will be returned. We assume that the user has prepared a list of stopwords in English and Spanish. In this example, a file for stopwords in English and another in Spanish.

# %%
# !python3 coveet.py tidy -file dhcovid_2020-5-8_2020-5-14_en_es_ar_co_ec_es_fl_mx_pe.csv -stopwords ../stopwords/stopwords_en.txt ../stopwords/stopwords_es.txt ../stopwords/stopwords_hashtags.txt
# Out:
# Namespace(file='dhcovid_2020-5-8_2020-5-14_en_es_ar_co_ec_es_fl_mx_pe.csv', func=<function handle_tidy at 0x7f5067439670>, lemmatize=False, search=None, stopwords=['../stopwords/stopwords_en.txt', '../stopwords/stopwords_es.txt', '../stopwords/stopwords_hashtags.txt'])
# wrote tidied df to dhcovid_2020-5-8_2020-5-14_en_es_ar_co_ec_es_fl_mx_pe_stopworded.csv 🎉

# %% [markdown]
# Stopword elimination and lemmatization can be done at the same time. This is how the above command would be amended to include lemmatization. __Expect this to take about ~30 minutes to complete.__

# %%
# !python3 coveet.py tidy -file dhcovid_2020-5-8_2020-5-14_en_es_ar_co_ec_es_fl_mx_pe.csv -lemmatize -stopwords ../stopwords/stopwords_en.txt ../stopwords/stopwords_es.txt ../stopwords/stopwords_hashtags.txt

# %% [markdown]
# Let's load in the tidied CSV with `pandas` again.

# %%
df = pd.read_csv('dhcovid_2020-5-8_2020-5-14_en_es_ar_co_ec_es_fl_mx_pe_stopworded.csv', index_col=0)

# %%
df
# Out:
#               date lang geo  \
# 0       2020-05-08   es  fl
# 1       2020-05-08   es  fl
# 2       2020-05-08   es  fl
# 3       2020-05-08   es  fl
# 4       2020-05-08   es  fl
# ...            ...  ...  ..
# 224732  2020-05-14   en  fl
# 224733  2020-05-14   en  fl
# 224734  2020-05-14   en  fl
# 224735  2020-05-14   en  fl
# 224736  2020-05-14   en  fl
#
#                                                                                                                                                                       text  \
# 0                                                                                                                          muere enfermero cubano atendia pacientes caribe
# 1                                                                                                trump desmonta incursion frustrada regimen mandaria grupito sino ejercito
# 2                                                                                                                          muere niño años nueva york enfermedad vinculada
# 3                                                                                  corresponsal medico principal explico cuales factores riesgo frecuentes hombres mujeres
# 4                                                                                                                 quedarse siempre advertencia cientifico ruso coronavirus
# ...                                                                                                                                                                    ...
# 224732                                                                                                                     breaking dr fauci proclaims vaccines ready fall
# 224733           sec filing dating week uber disclosed plans layoff 3700 employees figure amounts percent ride hailing giantrsquos total workforce document company states
# 224734  join ms focus teleconference designed help improve life ms expert speaker mitzi williams md topic care minorities join teleconference 7207409380 preregister today
# 224735                                                                                                                      emotional roi key performance indicators video
# 224736                                                                                                                 coronavirus suppression expert recommendations beat
#
#                            hashtags
# 0                               NaN
# 1       #internacionales #cambioweb
# 2                               NaN
# 3             #diariodelcoronavirus
# 4       #internacionales #cambioweb
# ...                             ...
# 224732                          NaN
# 224733                          NaN
# 224734                          NaN
# 224735                          NaN
# 224736                          NaN
#
# [224737 rows x 5 columns]

# %% [markdown]
# Much better :-) Before moving on, let's convert the date column to a `datetime` object since that makes working with dates easier. We will also turn the text and hashtags into lists which will ease processing later on.

# %%
df['date'] = pd.to_datetime(df['date'])
df['text'] = df['text'].str.split()
df['hashtags'] = df['hashtags'].str.split()

# %% [markdown]
# ## 3. Retrieving top n-grams or hashtags
#
# Let's have a look at the top 10 results in each area. First, we define some variables.

# %%
top_n = 10  # top 10 words
n_gram = 1  # ask for word frequency (i.e. an n-gram where n=1)

# %% [markdown]
# Let's toggle a variable to determine whether we will retrieve n-grams or hashtags.

# %%
col_name = 'text'  # set to either 'text' or 'hashtags'

# %% [markdown]
# We'll subset the dataframe to contain only tweets or hashtags based on this toggle variable, and drop any cells with missing values (due to a tweet consisting of a body but with no hashtags, or vice versa).

# %%
df = df.dropna(subset=[col_name])

# %% [markdown]
# We will create another dictionary where each key is a location-language pair, and the value is a list of the top occurrences under that setting. The code here invokes a function `count_ngrams()` from coveet to prepare the top n-gram and hashtag information.
#
# A brief note on how these n-grams are obtained: I treat the full tweet as context, rather than adjacent neighbors, in light of how short a "tweet" unit is. For instance, when obtaining bigrams, I consider the occurrence of two words together in a tweet as bigrams, regardless of whether they are adjacent. This could lead to possibly interesting findings, but we should discuss.

# %%
# counts is of the form: location, language, actual tuples
# count_ngrams returns a (default) dictionary of word tuples (ngrams) 
# with its associated frequency; we then use Counter from python collections 
# to tell us the top n most popular ones 
counts = {(g, l): Counter(count_ngrams(t, n_gram, consecutive=False)).most_common(top_n)
          for (g, l), t in df.groupby(["geo", "lang"])[col_name]}

# %% [markdown]
# Let's have a look at what we just did.

# %%
pprint(counts)
# Out:
# {('ar', 'es'): [(('casos',), 1789),
#                 (('pandemia',), 920),
#                 (('coronavirus',), 823),
#                 (('nuevos',), 766),
#                 (('hoy',), 727),
#                 (('salud',), 629),
#                 (('argentina',), 622),
#                 (('pais',), 582),
#                 (('personas',), 517),
#                 (('cuarentena',), 505)],
#  ('co', 'es'): [(('casos',), 4577),
#                 (('salud',), 2648),
#                 (('pandemia',), 2370),
#                 (('colombia',), 2189),
#                 (('hoy',), 2001),
#                 (('nuevos',), 1889),
#                 (('mayo',), 1867),
#                 (('coronavirus',), 1866),
#                 (('medidas',), 1704),
#                 (('pais',), 1703)],
#  ('ec', 'es'): [(('casos',), 1019),
#                 (('salud',), 923),
#                 (('ecuador',), 726),
#                 (('pandemia',), 722),
#                 (('contagio',), 603),
#                 (('mayo',), 558),
#                 (('emergencia',), 542),
#                 (('pais',), 517),
#                 (('pruebas',), 482),
#                 (('hoy',), 472)],
#  ('es', 'es'): [(('crisis',), 3513),
#                 (('coronavirus',), 2275),
#                 (('españa',), 2174),
#                 (('pandemia',), 1962),
#                 (('hoy',), 1722),
#                 (('gobierno',), 1652),
#                 (('frente',), 1610),
#                 (('medidas',), 1501),
#                 (('personas',), 1490),
#                 (('casos',), 1425)],
#  ('fl', 'en'): [(('pandemic',), 352),
#                 (('people',), 268),
#                 (('coronavirus',), 265),
#                 (('trump',), 214),
#                 (('cases',), 210),
#                 (('florida',), 209),
#                 (('help',), 183),
#                 (('health',), 166),
#                 (('like',), 161),
#                 (('video',), 160)],
#  ('fl', 'es'): [(('casos',), 165),
#                 (('pandemia',), 110),
#                 (('coronavirus',), 94),
#                 (('nuevos',), 72),
#                 (('florida',), 65),
#                 (('muertes',), 65),
#                 (('positivo',), 63),
#                 (('eeuu',), 63),
#                 (('pais',), 62),
#                 (('fallecidos',), 60)],
#  ('mx', 'es'): [(('casos',), 10595),
#                 (('mexico',), 8263),
#                 (('pandemia',), 6020),
#                 (('salud',), 5896),
#                 (('contagios',), 4858),
#                 (('personas',), 3806),
#                 (('coronavirus',), 3768),
#                 (('mayo',), 3764),
#                 (('pacientes',), 3618),
#                 (('gobierno',), 3533)],
#  ('pe', 'es'): [(('coronavirus',), 1318),
#                 (('peru',), 1178),
#                 (('casos',), 876),
#                 (('salud',), 875),
#                 (('pandemia',), 633),
#                 (('hoy',), 571),
#                 (('cuarentena',), 552),
#                 (('pacientes',), 484),
#                 (('emergencia',), 471),
#                 (('gobierno',), 455)]}

# %% [markdown]
# ## 4. Visualization

# %% [markdown]
# Now we're ready to visualize! Let's begin with a simple tabular representation of the data.

# %% [markdown]
# ### 4.1. Tabular representation

# %%
tab_df_data = {}
for gl, word_counts in counts.items():
    gl_data = {'word' : [], '# occurrences' : [], 'percentage': []}
    sub_df = df[(df['geo'] == gl[0]) & (df['lang'] == gl[1])]
    for w in word_counts:
        # append a row to the dictionary 
        gl_data['word'].append(" ".join(w[0]))
        gl_data['# occurrences'].append(w[1])
        gl_data['percentage'].append(round(w[1] / len(sub_df), 2))
    tab_df_data[gl] = pd.DataFrame(gl_data)

# %% [markdown]
# The variable `tab_df_data` is a dictionary of `pandas` dataframes, where each contains a summary of the frequency analysis for that geo-lang pair. The table has the following columns:
#
# * `word`, the top word, e.g. `casos`
# * `# occurrences`, the number of occurrences of that word with respect to the tweets in the queried geo-lang region
# * `percentage`, the percentage of occurrences of that word, again with respect to the tweets in the queried geo-lang region
#
# As an example, let's inspect the (`fl`, `es`) region.

# %%
tab_df_data[('fl', 'es')]
# Out:
#           word  # occurrences  percentage
# 0        casos            165        0.11
# 1     pandemia            110        0.07
# 2  coronavirus             94        0.06
# 3       nuevos             72        0.05
# 4      florida             65        0.04
# 5      muertes             65        0.04
# 6     positivo             63        0.04
# 7         eeuu             63        0.04
# 8         pais             62        0.04
# 9   fallecidos             60        0.04

# %% [markdown]
# Let's do one more check, this time with (`fl`, `en`).

# %%
tab_df_data[('fl', 'en')]
# Out:
#           word  # occurrences  percentage
# 0     pandemic            352        0.07
# 1       people            268        0.05
# 2  coronavirus            265        0.05
# 3        trump            214        0.04
# 4        cases            210        0.04
# 5      florida            209        0.04
# 6         help            183        0.04
# 7       health            166        0.03
# 8         like            161        0.03
# 9        video            160        0.03

# %% [markdown]
# ### 4.2. Bar chart matrix

# %% [markdown]
# Next, we move to a more visual representation of the results using a bar chart matrix. First we initialize some `matplotlib`  settings.

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 40, 40  # setting figure size
plt.rcParams.update({'font.size': 22})  # setting font size

# %% [markdown]
# We create a matrix of bar charts, one for each location-language pair. The order visualization can be reversed by toggling the `invert_yaxis()` function call in `plot_bar_matrix()`.

# %%
def plot_bar_matrix(counts, num_top_words, num_cols=2):
    """
    function for plotting a matrix of bar plots 
    
    counts: a dictionary mapping from a geo-lang pair identifier (generalizable to any identifier)
            to a list of (word, count) tuples containing the top word frequencies
    num_cols: desired number of columns to show in the grid
    str_func: function for "pretty printing" the title used in each of the bar charts  
    """
    # automatically determine the grid to use based on desired number of columns 
    num_rows = len(counts.keys()) // num_cols
    num_rows += 1 if num_rows * num_cols < len(counts.keys()) else 0
    fig, axes = plt.subplots(num_rows, num_cols)
    flattened = axes.flatten()
    for i, (id_pair, counts) in enumerate(counts.items()):
        labels = [" ".join(w) for w, _ in counts]
        y = [n for _, n in counts]
        cmap = plt.get_cmap('spring')
        colors = plt.get_cmap('spring')(np.linspace(0, 1, len(labels)))
        flattened[i].set_title(f"{' '.join([str(p) for p in id_pair])}")
        flattened[i].barh(y=range(0, num_top_words), width=y, color=colors, tick_label=labels) # range should equal to the # of top words you want to retrieve.
        flattened[i].invert_yaxis()  # reverse the visualization order along the y-axis

# %%
plot_bar_matrix(counts, num_top_words = 10, num_cols = 2)

# %% [markdown]
# ## 5. More advanced explorations
#
# In this final part of the notebook, I introduce two different analyses that can enable more advanced explorations of the tweet data: (1) unique words by location-language pair mode, and (2) unique words by date mode. We will still be making use of the tweet data we queried earlier in the notebook, available in `df`.

# %% [markdown]
# ### 5.1. Unique words by location-language pair mode

# %% [markdown]
# We may be interested in obtaining words that are *unique* to a location-language pair, i.e., for an input file that contains information about `mx-es`, `es-es`, and `fl-es`, words that occur *only* in `mx-es` and not in `es-es` and `fl-es`.
#
# We can invoke the function `uniq_vocab_by_group()` from *coveet* to retrieve a dictionary for a location-language pair's unique vocabulary, and filter `df` with that dictionary using `apply()` from `pandas`. Put less technically, each row of `df` will only contain words/hashtags that are unique to that location-language pair.

# %%
col_name = "text"

# %%
grouping = df.groupby(["geo", "lang"])[col_name]
vocab_dic = uniq_vocab_by_group(grouping)  # unique vocab dictionary 
df[col_name] = df.apply(lambda x : set(x[col_name]) & vocab_dic[(x['geo'], x['lang'])],
                        result_type='reduce', axis=1)  # filtering tweets by that dic

# %% [markdown]
# Let's visualize top frequencies!

# %%
counts = {k: Counter(count_ngrams(t, n_gram, consecutive=False)).most_common(top_n) for k, t in grouping}

# %%
pprint(counts)
# Out:
# {('ar', 'es'): [(('astori',), 67),
#                 (('bonaerense',), 36),
#                 (('amba',), 35),
#                 (('macri',), 35),
#                 (('conurbano',), 32),
#                 (('asse',), 25),
#                 (('porteñas',), 24),
#                 (('0420',), 22),
#                 (('quilmes',), 22),
#                 (('sinae',), 20)],
#  ('co', 'es'): [(('boyaca',), 147),
#                 (('monteria',), 95),
#                 (('corabastos',), 64),
#                 (('tunja',), 62),
#                 (('cucuta',), 60),
#                 (('bucaramanga',), 58),
#                 (('panameños',), 45),
#                 (('veraguas',), 41),
#                 (('manizales',), 41),
#                 (('panameña',), 41)],
#  ('ec', 'es'): [(('ñuka',), 8),
#                 (('09d01',), 8),
#                 (('may2021',), 8),
#                 (('inalterable',), 8),
#                 (('577',), 8),
#                 (('ambato',), 8),
#                 (('recuerdelo',), 8),
#                 (('weir',), 7),
#                 (('archidonense',), 7),
#                 (('delcontagio',), 6)],
#  ('es', 'es'): [(('albacete',), 80),
#                 (('ceuta',), 64),
#                 (('almeria',), 61),
#                 (('baleares',), 51),
#                 (('crise',), 49),
#                 (('pola',), 48),
#                 (('epis',), 43),
#                 (('ourense',), 38),
#                 (('ucar',), 38),
#                 (('melilla',), 37)],
#  ('fl', 'en'): [(('tested',), 92),
#                 (('businesses',), 87),
#                 (('states',), 86),
#                 (('possible',), 75),
#                 (('responders',), 72),
#                 (('reopen',), 72),
#                 (('important',), 58),
#                 (('weeks',), 57),
#                 (('every',), 56),
#                 (('government',), 51)],
#  ('fl', 'es'): [(('05072020',), 25),
#                 (('05052020',), 18),
#                 (('3058563139',), 5),
#                 (('33172',), 5),
#                 (('prociudadanos',), 5),
#                 (('guarenas',), 4),
#                 (('miamimundo',), 3),
#                 (('7pm6c',), 3),
#                 (('moody',), 3),
#                 (('maiquetia',), 2)],
#  ('mx', 'es'): [(('oaxaca',), 689),
#                 (('jalisco',), 574),
#                 (('edomex',), 475),
#                 (('tamaulipas',), 357),
#                 (('tlaxcala',), 328),
#                 (('coahuila',), 259),
#                 (('mexiquenses',), 248),
#                 (('guanajuato',), 223),
#                 (('pemex',), 203),
#                 (('panteones',), 200)],
#  ('pe', 'es'): [(('maguiña',), 89),
#                 (('lambayeque',), 54),
#                 (('villaran',), 35),
#                 (('ancash',), 32),
#                 (('yoshiyama',), 32),
#                 (('tarija',), 25),
#                 (('diresa',), 24),
#                 (('80604',), 24),
#                 (('tumbes',), 23),
#                 (('bucana',), 22)]}

# %%
plot_bar_matrix(counts, num_top_words = 10, num_cols = 2)

# %% [markdown]
# Note the words that are most frequent using this method and how it is (or isn't?) in conversation with the pandemic. Some surprising results can be observed: in `fl es`, the phone number `3058563139` is unique to Florida-Spanish and occurs frequently enough to make the top list. A quick search reveals this is the contact information for an immigration attorney.

# %% [markdown]
# ### 5.2 Unique words by date mode

# %% [markdown]
# Instead of obtaining words that are unique with respect to a location-language pair, we may be interested in retrieving words that are unique with respect to a given __date__. For instance, during the week of May 8, we may be interested in the words that occurred *only* on May 8, on May 9, and so on. This can help us understand trends.
#
# The work needed to accomplish this is analogous to Section 4.2. However, unlike the unique word mode for location-language pairs, this mode is best suited for studies on individual countries, e.g., the unique words by date in `fl-es`. Let's try this mode for `fl-es` during the week of May 8.

# %% [markdown]
# First, we need to prepare a query CSV with the contents of `fl-es` only. Remember that `coveet` is general and will work with whatever data is present in the CSV.

# %%
# !python3 coveet.py query -g fl -l es -d 2020-05-08 2020-05-14
# Out:
# Namespace(all=False, date=[datetime.datetime(2020, 5, 8, 0, 0), datetime.datetime(2020, 5, 14, 0, 0)], func=<function handle_query at 0x7f7234bf44c0>, geo=['fl'], lang=['es'], search=None)
# wrote df to dhcovid_2020-5-8_2020-5-14_es_fl.csv 🎉

# %% [markdown]
# As before, we need to tidy up the query CSV. Because this is a smaller file, we can also demonstrate lemmatization here.

# %%
# !python3 coveet.py tidy -file dhcovid_2020-5-8_2020-5-14_es_fl.csv -lemmatize -stopwords ../stopwords/stopwords_en.txt ../stopwords/stopwords_es.txt ../stopwords/stopwords_hashtags.txt
# Out:
# Namespace(file='dhcovid_2020-5-8_2020-5-14_es_fl.csv', func=<function handle_tidy at 0x7f45ca8df5e0>, lemmatize=True, search=None, stopwords=['../stopwords/stopwords_en.txt', '../stopwords/stopwords_es.txt', '../stopwords/stopwords_hashtags.txt'])
# Loading required package: udpipe
# Package udpipe already installed.
# Loading required package: data.table
# Package data.table already installed.
# Loading required package: tidyverse
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.0 ──
# ✔ ggplot2 3.3.2     ✔ purrr   0.3.4
# ✔ tibble  3.0.3     ✔ dplyr   1.0.1
# ✔ tidyr   1.1.0     ✔ stringr 1.4.0
# ✔ readr   1.3.1     ✔ forcats 0.5.0
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::between()   masks data.table::between()
# ✖ dplyr::filter()    masks stats::filter()
# ✖ dplyr::first()     masks data.table::first()
# ✖ dplyr::lag()       masks stats::lag()
# ✖ dplyr::last()      masks data.table::last()
# ✖ purrr::transpose() masks data.table::transpose()
# Package tidyverse already installed.
# [[1]]
# NULL
#
# [[2]]
# NULL
#
# [[3]]
# NULL
#
# [1] "dhcovid_2020-5-8_2020-5-14_es_fl.csv"
# [2] "2"
# [3] "dhcovid_2020-5-8_2020-5-14_es_fl_udpipe.csv"
# Parsed with column specification:
# cols(
#   X1 = col_double(),
#   date = col_date(format = ""),
#   lang = col_character(),
#   geo = col_character(),
#   text = col_character(),
#   hashtags = col_character()
# )
# Warning message:
# Missing column names filled in: 'X1' [1]
# [1] "running udpipe es now.."
# [1] "running udpipe en now.."
# Warning message:
# In read_connlu(x, is_udpipe_annotation = TRUE, ...) :
#   No parsed data in x$conllu, returning default empty data.frame. Error message at x$error indicates e.g.:
# [1] "finished running udpipe"
# wrote tidied df to dhcovid_2020-5-8_2020-5-14_es_fl_stopworded_lemmatized.csv 🎉

# %% [markdown]
# We read in the tidy CSV into a pandas data frame and do the usual pandas preprocessing work.

# %%
df = pd.read_csv('dhcovid_2020-5-8_2020-5-14_es_fl_stopworded_lemmatized.csv')
df['date'] = pd.to_datetime(df['date'])
df['text'] = df['text'].str.split()
df['hashtags'] = df['hashtags'].str.split()

# %% [markdown]
# We prepare the unique vocabulary dictionary as we did earlier, and then obtain `counts`.

# %%
col_name = "text"

# %%
grouping = df.groupby([pd.Grouper(key='date', freq='D'), "geo", "lang"])[col_name]  # D or W-MON
vocab_dic = uniq_vocab_by_group(grouping)  # unique vocab dictionary 
# recall that col_name is a toggle variable set earlier in the notebook ("text" or "hashtags")
df[col_name] = df.apply(lambda x : set(x[col_name]) & vocab_dic[(x['date'], x["geo"], x["lang"])],
                        result_type='reduce', axis=1)  # filtering tweets by that dic
# note to jerry: remember to un-tuple if the id pairs are date only

# %%
counts = {k: Counter(count_ngrams(t, n_gram, consecutive=False)).most_common(top_n) for k, t in grouping }

# %% [markdown]
# We print `counts` for inspection. Note how the key in this dictionary is not a `geo-lang` pair, but rather a `date-geo-lang` pair.

# %%
pprint(counts)
# Out:
# {(Timestamp('2020-05-08 00:00:00', freq='D'), 'fl', 'es'): [(('comprobar',), 4),
#                                                             (('madonna',), 4),
#                                                             (('homenaje',), 3),
#                                                             (('29',), 3),
#                                                             (('cadaver',), 3),
#                                                             (('381',), 3),
#                                                             (('orlar',), 3),
#                                                             (('odio',), 3),
#                                                             (('2400',), 3),
#                                                             (('petare',), 3)],
#  (Timestamp('2020-05-09 00:00:00', freq='D'), 'fl', 'es'): [(('playa',), 3),
#                                                             (('consolidar',),
#                                                              3),
#                                                             (('brasileño',), 3),
#                                                             (('clinico',), 3),
#                                                             (('7pm6c',), 3),
#                                                             (('secuela',), 3),
#                                                             (('77000',), 3),
#                                                             (('1715',), 2),
#                                                             (('ambulancia',),
#                                                              2),
#                                                             (('tuna',), 2)],
#  (Timestamp('2020-05-10 00:00:00', freq='D'), 'fl', 'es'): [(('pm',), 3),
#                                                             (('cancer',), 2),
#                                                             (('autoracer',), 2),
#                                                             (('56',), 2),
#                                                             (('hondura',), 2),
#                                                             (('guerrero',), 2),
#                                                             (('dinamico',), 2),
#                                                             (('municipio',), 2),
#                                                             (('inflexion',), 2),
#                                                             (('urss',), 2)],
#  (Timestamp('2020-05-11 00:00:00', freq='D'), 'fl', 'es'): [(('indico',), 3),
#                                                             (('piratear',), 3),
#                                                             (('35022',), 3),
#                                                             (('3465',), 3),
#                                                             (('vision',), 2),
#                                                             (('18',), 2),
#                                                             (('1735',), 2),
#                                                             (('empeorar',), 2),
#                                                             (('super',), 2),
#                                                             (('vivencia',), 2)],
#  (Timestamp('2020-05-12 00:00:00', freq='D'), 'fl', 'es'): [(('placenta',), 4),
#                                                             (('alternativo',),
#                                                              4),
#                                                             (('reactivacion',),
#                                                              3),
#                                                             (('escapar',), 3),
#                                                             (('dengar',), 3),
#                                                             (('contenido',), 3),
#                                                             (('twitter',), 3),
#                                                             (('gable',), 3),
#                                                             (('coral',), 3),
#                                                             (('extendio',), 2)],
#  (Timestamp('2020-05-13 00:00:00', freq='D'), 'fl', 'es'): [(('imprudente',),
#                                                              4),
#                                                             (('duque',), 3),
#                                                             (('2329',), 3),
#                                                             (('interino',), 2),
#                                                             (('michael',), 2),
#                                                             (('subsecretario',),
#                                                              2),
#                                                             (('prestigioso',),
#                                                              2),
#                                                             (('439',), 2),
#                                                             (('subsistir',), 2),
#                                                             (('rber',), 2)],
#  (Timestamp('2020-05-14 00:00:00', freq='D'), 'fl', 'es'): [(('actriz',), 5),
#                                                             (('sacrificar',),
#                                                              5),
#                                                             (('periodo',), 4),
#                                                             (('invierno',), 4),
#                                                             (('cabello',), 3),
#                                                             (('perseguir',), 3),
#                                                             (('prioridad',), 3),
#                                                             (('sanofi',), 3),
#                                                             (('polemico',), 3),
#                                                             (('pronostican',),
#                                                              3)]}

# %%
plot_bar_matrix(counts, num_top_words = 10, num_cols = 2)

# %% [markdown]
# Note the very low frequency of words in this bar plot matrix, when compared to the unique words by location-language mode. That points to the idea that the vocabulary space of a location-language pair tends to be consistent from day to day. Some things to consider for experimentation:
#
# * What happens when trying this mode in different weeks, e.g., the period immediately preceeding/following the spike of cases in Florida? Does the vocabulary space still remain consistent?
# * How about for location-language pairs other than `fl-es`?
# * Rather than day-by-day analysis, considering week-by-week or month-by-month analysis, i.e., the week becomes the unit of measure rather than the day.
