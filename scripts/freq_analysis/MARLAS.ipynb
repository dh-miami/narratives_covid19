# %% [markdown]
# # Digital Narratives of Covid-19 through Twitter Mining (MARLAS Journal)

# %%
import numpy as np
import pandas as pd
from coveet import count_ngrams, uniq_vocab_by_group
from collections import Counter
from pprint import pprint
import matplotlib.pyplot as plt

pd.set_option('display.max_colwidth', None)
pd.options.mode.chained_assignment = None

# %% [markdown]
# ## I. Tweet queries from April 25, 2020 to May 25, 2020:

# %%
# !python3 coveet.py query -g ar co ec mx pe -l es -d 2020-04-25 2020-05-25 # do not run it twice!
# Out:
# Namespace(all=False, date=[datetime.datetime(2020, 4, 25, 0, 0), datetime.datetime(2020, 5, 25, 0, 0)], func=<function handle_query at 0x7fe835421550>, geo=['ar', 'co', 'ec', 'mx', 'pe'], lang=['es'], search=None)
# ^C
# Traceback (most recent call last):
#   File "coveet.py", line 373, in <module>
#     args.func(args)
#   File "coveet.py", line 108, in handle_query
#     df = get_data_df(args.lang, args.geo, start_date, end_date)
#   File "coveet.py", line 50, in get_data_df
#     tweets = requests.get(query_url(l, g, date), stream=True).text
#   File "/home/jbonnell/.pyenv/versions/3.8.3/lib/python3.8/site-packages/requests/models.py", line 858, in text
#     encoding = self.apparent_encoding
#   File "/home/jbonnell/.pyenv/versions/3.8.3/lib/python3.8/site-packages/requests/models.py", line 728, in apparent_encoding
#     return chardet.detect(self.content)['encoding']
#   File "/home/jbonnell/.pyenv/versions/3.8.3/lib/python3.8/site-packages/chardet/__init__.py", line 38, in detect
#     detector.feed(byte_str)
#   File "/home/jbonnell/.pyenv/versions/3.8.3/lib/python3.8/site-packages/chardet/universaldetector.py", line 211, in feed
#     if prober.feed(byte_str) == ProbingState.FOUND_IT:
#   File "/home/jbonnell/.pyenv/versions/3.8.3/lib/python3.8/site-packages/chardet/charsetgroupprober.py", line 71, in feed
#     state = prober.feed(byte_str)
#   File "/home/jbonnell/.pyenv/versions/3.8.3/lib/python3.8/site-packages/chardet/utf8prober.py", line 67, in feed
#     if self.coding_sm.get_current_charlen() >= 2:
#   File "/home/jbonnell/.pyenv/versions/3.8.3/lib/python3.8/site-packages/chardet/codingstatemachine.py", line 81, in get_current_charlen
#     return self._curr_char_len
# KeyboardInterrupt

# %%
df = pd.read_csv('dhcovid_2020-4-25_2020-5-25_es_ar_co_ec_mx_pe.csv', index_col=0)

# %% [markdown]
# Tidy file by removing stopwords:

# %%
# !python3 coveet.py tidy -file dhcovid_2020-4-25_2020-5-25_es_ar_co_ec_mx_pe.csv -stopwords ../stopwords/stopwords_es.txt ../stopwords/stopwords_hashtags.txt
# Out:
# Namespace(file='dhcovid_2020-4-25_2020-5-25_es_ar_co_ec_mx_pe.csv', func=<function handle_tidy at 0x7fddd2dc0670>, lemmatize=False, search=None, stopwords=['../stopwords/stopwords_es.txt', '../stopwords/stopwords_hashtags.txt'])
# wrote tidied df to dhcovid_2020-4-25_2020-5-25_es_ar_co_ec_mx_pe_stopworded.csv 🎉

# %%
df = pd.read_csv('dhcovid_2020-4-25_2020-5-25_es_ar_co_ec_mx_pe_stopworded.csv', index_col=0) # run from here using this file

# %%
df['date'] = pd.to_datetime(df['date'])
df['text'] = df['text'].str.split()
df['hashtags'] = df['hashtags'].str.split()

# %% [markdown]
# ### Top 30 words:

# %%
top_n = 30  # top 30 words
n_gram = 1  # ask for word frequency (i.e. an n-gram where n=1)
col_name = 'text'  # set to either 'text' or 'hashtags'
df_text = df.dropna(subset=[col_name])
counts = {(g, l): Counter(count_ngrams(t, n_gram, consecutive=False)).most_common(top_n)
          for (g, l), t in df_text.groupby(["geo", "lang"])[col_name]}

# %%
pprint(counts)
# Out:
# {('ar', 'es'): [(('casos',), 8233),
#                 (('coronavirus',), 4061),
#                 (('pandemia',), 4022),
#                 (('hoy',), 3567),
#                 (('nuevos',), 3459),
#                 (('salud',), 2941),
#                 (('argentina',), 2815),
#                 (('pais',), 2765),
#                 (('personas',), 2643),
#                 (('cuarentena',), 2532),
#                 (('positivos',), 2263),
#                 (('situacion',), 2201),
#                 (('caso',), 2002),
#                 (('covid',), 1825),
#                 (('muertes',), 1784),
#                 (('gente',), 1730),
#                 (('nuevo',), 1726),
#                 (('mundo',), 1724),
#                 (('gobierno',), 1699),
#                 (('test',), 1629),
#                 (('provincia',), 1574),
#                 (('positivo',), 1567),
#                 (('pacientes',), 1526),
#                 (('mayo',), 1479),
#                 (('años',), 1477),
#                 (('virus',), 1436),
#                 (('confirmados',), 1402),
#                 (('total',), 1378),
#                 (('ciudad',), 1357),
#                 (('uruguay',), 1322)],
#  ('co', 'es'): [(('casos',), 20090),
#                 (('salud',), 11349),
#                 (('pandemia',), 10761),
#                 (('colombia',), 9429),
#                 (('hoy',), 8793),
#                 (('pais',), 8417),
#                 (('coronavirus',), 8319),
#                 (('nuevos',), 8287),
#                 (('personas',), 7524),
#                 (('medidas',), 7511),
#                 (('mayo',), 7293),
#                 (('gobierno',), 6644),
#                 (('pacientes',), 6413),
#                 (('pruebas',), 6173),
#                 (('crisis',), 6106),
#                 (('emergencia',), 5976),
#                 (('contagio',), 4871),
#                 (('fallecidos',), 4870),
#                 (('cuarentena',), 4759),
#                 (('nacional',), 4645),
#                 (('muertes',), 4615),
#                 (('contagios',), 4545),
#                 (('mundo',), 4297),
#                 (('atencion',), 4202),
#                 (('virus',), 4140),
#                 (('recuperados',), 4016),
#                 (('frente',), 4004),
#                 (('tiempos',), 3942),
#                 (('evitar',), 3677),
#                 (('prevencion',), 3670)],
#  ('ec', 'es'): [(('casos',), 4605),
#                 (('salud',), 3898),
#                 (('ecuador',), 3753),
#                 (('pandemia',), 3376),
#                 (('pruebas',), 3044),
#                 (('mayo',), 2805),
#                 (('emergencia',), 2775),
#                 (('personas',), 2644),
#                 (('pais',), 2584),
#                 (('hoy',), 2291),
#                 (('gobierno',), 2181),
#                 (('medidas',), 2151),
#                 (('quito',), 2142),
#                 (('pacientes',), 2135),
#                 (('sanitaria',), 2047),
#                 (('coronavirus',), 2019),
#                 (('atencion',), 1998),
#                 (('crisis',), 1759),
#                 (('nacional',), 1632),
#                 (('fallecidos',), 1600),
#                 (('evitar',), 1591),
#                 (('contagio',), 1550),
#                 (('mundo',), 1436),
#                 (('confirmados',), 1410),
#                 (('virus',), 1328),
#                 (('situacion',), 1318),
#                 (('contagios',), 1287),
#                 (('propagacion',), 1265),
#                 (('detalles',), 1260),
#                 (('trabajo',), 1215)],
#  ('mx', 'es'): [(('casos',), 48262),
#                 (('mexico',), 35353),
#                 (('pandemia',), 26471),
#                 (('salud',), 25707),
#                 (('contagios',), 20529),
#                 (('personas',), 17210),
#                 (('coronavirus',), 16431),
#                 (('medidas',), 15745),
#                 (('pacientes',), 15499),
#                 (('gobierno',), 14594),
#                 (('hoy',), 14170),
#                 (('contingencia',), 14042),
#                 (('muertes',), 13804),
#                 (('mayo',), 13123),
#                 (('casa',), 11338),
#                 (('confirmados',), 11331),
#                 (('hospital',), 11143),
#                 (('nuevos',), 10579),
#                 (('positivos',), 10554),
#                 (('estado',), 10318),
#                 (('pais',), 10031),
#                 (('contagio',), 9720),
#                 (('defunciones',), 9614),
#                 (('personal',), 9514),
#                 (('evitar',), 9231),
#                 (('crisis',), 8960),
#                 (('positivo',), 8422),
#                 (('informacion',), 8316),
#                 (('pruebas',), 8218),
#                 (('sanitaria',), 7900)],
#  ('pe', 'es'): [(('coronavirus',), 5787),
#                 (('peru',), 5596),
#                 (('casos',), 4189),
#                 (('salud',), 3595),
#                 (('pandemia',), 2806),
#                 (('cuarentena',), 2531),
#                 (('hoy',), 2521),
#                 (('pacientes',), 2318),
#                 (('personas',), 2275),
#                 (('pais',), 2207),
#                 (('fallecidos',), 1962),
#                 (('gobierno',), 1954),
#                 (('emergencia',), 1906),
#                 (('positivo',), 1848),
#                 (('pruebas',), 1809),
#                 (('estado',), 1601),
#                 (('vizcarra',), 1592),
#                 (('hospital',), 1523),
#                 (('mayo',), 1502),
#                 (('presidente',), 1420),
#                 (('medidas',), 1401),
#                 (('mundo',), 1348),
#                 (('medicos',), 1297),
#                 (('lima',), 1261),
#                 (('ministro',), 1219),
#                 (('contagio',), 1206),
#                 (('muertos',), 1170),
#                 (('crisis',), 1155),
#                 (('prueba',), 1143),
#                 (('infectados',), 1134)]}

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 40, 40  # setting figure size
plt.rcParams.update({'font.size': 22})  # setting font size

# %%
def plot_bar_matrix(counts, num_top_words, num_cols=2):
    """
    function for plotting a matrix of bar plots 
    
    counts: a dictionary mapping from a geo-lang pair identifier (generalizable to any identifier)
            to a list of (word, count) tuples containing the top word frequencies
    num_cols: desired number of columns to show in the grid
    str_func: function for "pretty printing" the title used in each of the bar charts  
    """
    # automatically determine the grid to use based on desired number of columns 
    num_rows = len(counts.keys()) // num_cols
    num_rows += 1 if num_rows * num_cols < len(counts.keys()) else 0
    fig, axes = plt.subplots(num_rows, num_cols)
    flattened = axes.flatten()
    for i, (id_pair, counts) in enumerate(counts.items()):
        labels = [" ".join(w) for w, _ in counts]
        y = [n for _, n in counts]
        cmap = plt.get_cmap('spring')
        colors = plt.get_cmap('spring')(np.linspace(0, 1, len(labels)))
        flattened[i].set_title(f"{' '.join([str(p) for p in id_pair])}")
        flattened[i].barh(y=range(0, num_top_words), width=y, color=colors, tick_label=labels) # range should equal to the # of top words you want to retrieve.
        flattened[i].invert_yaxis()  # reverse the visualization order along the y-axis

# %%
plot_bar_matrix(counts, num_top_words = top_n, num_cols = 2)

# %% [markdown]
# ### Top 30 hashtags from April 25th yo May 25th

# %%
top_n = 30  # top 30 words
n_gram = 1  # ask for word frequency (i.e. an n-gram where n=1)
col_name = 'hashtags'  # set to either 'text' or 'hashtags'
df_text = df.dropna(subset=[col_name])
counts = {(g, l): Counter(count_ngrams(t, n_gram, consecutive=False)).most_common(top_n)
          for (g, l), t in df_text.groupby(["geo", "lang"])[col_name]}

# %%
pprint(counts)
# Out:
# {('ar', 'es'): [(('#quedateencasa',), 1193),
#                 (('#cuarentena',), 837),
#                 (('#argentina',), 595),
#                 (('#coronavirusargentina',), 515),
#                 (('#pandemia',), 486),
#                 (('#ahora',), 406),
#                 (('#yomequedoencasa',), 317),
#                 (('#argentinaunida',), 292),
#                 (('#noscuidamosentretodos',), 287),
#                 (('#quedateentucasa',), 266),
#                 (('#laplata',), 259),
#                 (('#afp',), 257),
#                 (('#cuidarteescuidarnos',), 253),
#                 (('#salud',), 206),
#                 (('#coronavirusenargentina',), 192),
#                 (('#ahoramontevideo',), 183),
#                 (('#covid19uruguay',), 174),
#                 (('#cordoba',), 170),
#                 (('#covid19argentina',), 170),
#                 (('#noticias',), 167),
#                 (('#uruguay',), 164),
#                 (('#uruguaydecide',), 161),
#                 (('#rosario',), 160),
#                 (('#coronavirusenuruguay',), 159),
#                 (('#santafe',), 145),
#                 (('#quilmes',), 143),
#                 (('#elecciones2020',), 139),
#                 (('#cordobaesp',), 131),
#                 (('#tuvoto',), 130),
#                 (('#cuarentenaextendida',), 117)],
#  ('co', 'es'): [(('#quedateencasa',), 5545),
#                 (('#disciplinaparavolver',), 2570),
#                 (('#atencion',), 1992),
#                 (('#prevencionyaccion',), 1824),
#                 (('#ecuador',), 1798),
#                 (('#colombia',), 1754),
#                 (('#cuarentena',), 1250),
#                 (('#evitaelcoronavirus',), 1175),
#                 (('#reportecovid19',), 1081),
#                 (('#salud',), 1075),
#                 (('#panama',), 1010),
#                 (('#yomequedoencasa',), 953),
#                 (('#noticiastvn',), 881),
#                 (('#envivo',), 752),
#                 (('#pandemia',), 642),
#                 (('#covid19ec',), 591),
#                 (('#somosunosomostodos',), 581),
#                 (('#cordoba',), 562),
#                 (('#quito',), 562),
#                 (('#empiezaportusmanos',), 527),
#                 (('#aestahora',), 525),
#                 (('#bogota',), 515),
#                 (('#venezuela',), 482),
#                 (('#ultimahora',), 462),
#                 (('#mundo',), 458),
#                 (('#conmedidassalvamosvidas',), 427),
#                 (('#noticias',), 424),
#                 (('#internacional',), 384),
#                 (('#nacionales',), 361),
#                 (('#treporta',), 346)],
#  ('ec', 'es'): [(('#ecuador',), 3294),
#                 (('#disciplinaparavolver',), 2571),
#                 (('#quedateencasa',), 2429),
#                 (('#covid19ec',), 1093),
#                 (('#atencion',), 939),
#                 (('#guayaquil',), 695),
#                 (('#quito',), 643),
#                 (('#urgente',), 472),
#                 (('#covid19ecuador',), 448),
#                 (('#aecuadorlosacamostodos',), 436),
#                 (('#conmedidassalvamosvidas',), 428),
#                 (('#cuenca',), 375),
#                 (('#cuarentena',), 374),
#                 (('#coronavirusenecuador',), 374),
#                 (('#noscuidamostodos',), 368),
#                 (('#emergenciasanitaria',), 355),
#                 (('#activadosporlasalud',), 332),
#                 (('#semaforoec',), 320),
#                 (('#coronavirusecuador',), 313),
#                 (('#noticias',), 304),
#                 (('#mundo',), 265),
#                 (('#ecuadorencrisis',), 223),
#                 (('#loja',), 221),
#                 (('#juntosecuador',), 218),
#                 (('#manabi',), 201),
#                 (('#sectoresquetrabajanporti',), 185),
#                 (('#elpeorgobiernodelahistoria',), 181),
#                 (('#yomequedoencasa',), 178),
#                 (('#semafororojoenquito',), 177),
#                 (('#salud',), 169)],
#  ('mx', 'es'): [(('#quedateencasa',), 25249),
#                 (('#covid19mx',), 22655),
#                 (('#mexico',), 7574),
#                 (('#cuidemostodosdetodos',), 6429),
#                 (('#enterate',), 6333),
#                 (('#nacional',), 4385),
#                 (('#oaxaca',), 3897),
#                 (('#covid19mexico',), 3556),
#                 (('#edomex',), 3540),
#                 (('#ultimahora',), 3044),
#                 (('#cdmx',), 2944),
#                 (('#puebla',), 2863),
#                 (('#salud',), 2643),
#                 (('#sanadistancia',), 2518),
#                 (('#internacional',), 2389),
#                 (('#noticias',), 2353),
#                 (('#enedomexpreveniressalud',), 2349),
#                 (('#cuarentena',), 2189),
#                 (('#pandemia',), 2165),
#                 (('#mexiquensesenriesgo',), 2006),
#                 (('#veracruz',), 1867),
#                 (('#mundo',), 1733),
#                 (('#video',), 1721),
#                 (('#preveniressalud',), 1704),
#                 (('#ir',), 1681),
#                 (('#fase3',), 1503),
#                 (('#slp',), 1452),
#                 (('#tamaulipas',), 1377),
#                 (('#local',), 1268),
#                 (('#noqueremosmasmentiras',), 1163)],
#  ('pe', 'es'): [(('#quedateencasa',), 1757),
#                 (('#peru',), 990),
#                 (('#yomequedoencasa',), 926),
#                 (('#bolivia',), 739),
#                 (('#cuarentena',), 680),
#                 (('#loultimo',), 609),
#                 (('#atvnoticiasmatinal',), 590),
#                 (('#coronavirusenperu',), 535),
#                 (('#mundo',), 493),
#                 (('#ultimo',), 373),
#                 (('#urgente',), 357),
#                 (('#estadodeemergencia',), 332),
#                 (('#fmbolivia',), 282),
#                 (('#peruestaennuestrasmanos',), 273),
#                 (('#covid19peru',), 264),
#                 (('#ahora',), 240),
#                 (('#p7informa',), 238),
#                 (('#pandemia',), 214),
#                 (('#panamericananoticias',), 195),
#                 (('#piura',), 192),
#                 (('#arequipa',), 187),
#                 (('#atencion',), 184),
#                 (('#coronavirusperu',), 183),
#                 (('#video',), 182),
#                 (('#vizcarra',), 179),
#                 (('#noticias',), 171),
#                 (('#24horas',), 162),
#                 (('#salud',), 144),
#                 (('#envivo',), 143),
#                 (('#dia65',), 135)]}

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 40, 40  # setting figure size
plt.rcParams.update({'font.size': 22})  # setting font size

# %%
plot_bar_matrix(counts, num_top_words = top_n, num_cols = 2)

# %% [markdown]
# ### Top 30 unique words

# %%
col_name = "text"

# %%
df = df.dropna(subset=[col_name])

# %%
grouping = df.groupby(["geo", "lang"])[col_name]
vocab_dic = uniq_vocab_by_group(grouping)  # unique vocab dictionary 
df[col_name] = df.apply(lambda x : set(x[col_name]) & vocab_dic[(x['geo'], x['lang'])],
                        result_type='reduce', axis=1)  # filtering tweets by that dic

# %%
counts = {k: Counter(count_ngrams(t, n_gram, consecutive=False)).most_common(top_n) for k, t in grouping}

# %%
pprint(counts)
# Out:
# {('ar', 'es'): [(('artigas',), 106),
#                 (('sinae',), 99),
#                 (('udelar',), 89),
#                 (('asse',), 85),
#                 (('chascomus',), 76),
#                 (('pba',), 74),
#                 (('astori',), 69),
#                 (('lanus',), 63),
#                 (('boludos',), 58),
#                 (('pehuajo',), 56),
#                 (('creuso',), 52),
#                 (('pelotuda',), 52),
#                 (('11114',), 51),
#                 (('18818',), 50),
#                 (('tacuarembo',), 49),
#                 (('porteñas',), 46),
#                 (('santafesino',), 44),
#                 (('intendenta',), 43),
#                 (('chacabuco',), 42),
#                 (('dnu',), 41),
#                 (('olavarria',), 41),
#                 (('catamarca',), 40),
#                 (('berisso',), 39),
#                 (('unlp',), 39),
#                 (('3607',), 38),
#                 (('18hs',), 38),
#                 (('cahn',), 38),
#                 (('tabare',), 37),
#                 (('pueyrredon',), 36),
#                 (('gualeguaychu',), 36)],
#  ('co', 'es'): [(('monteria',), 478),
#                 (('tunja',), 309),
#                 (('bucaramanga',), 298),
#                 (('veraguas',), 219),
#                 (('corabastos',), 196),
#                 (('barrancabermeja',), 178),
#                 (('duitama',), 166),
#                 (('risaralda',), 165),
#                 (('cdi',), 165),
#                 (('chiquinquira',), 111),
#                 (('soacha',), 106),
#                 (('quindio',), 104),
#                 (('coronapp',), 96),
#                 (('coviandes',), 89),
#                 (('ospina',), 88),
#                 (('7668',), 88),
#                 (('iibt',), 86),
#                 (('valledupar',), 81),
#                 (('quibdo',), 81),
#                 (('uis',), 79),
#                 (('dimayor',), 73),
#                 (('gnbtrabajajuntoalpueblo',), 71),
#                 (('envigado',), 70),
#                 (('ituango',), 70),
#                 (('lorica',), 68),
#                 (('4431',), 67),
#                 (('gnbesvzla',), 66),
#                 (('unicordoba',), 65),
#                 (('ecopetrol',), 65),
#                 (('gnbdefensadelpueblo',), 65)],
#  ('ec', 'es'): [(('archidonense',), 44),
#                 (('delcontagio',), 27),
#                 (('may2021',), 23),
#                 (('09d01',), 21),
#                 (('desterrando',), 20),
#                 (('ñuka',), 18),
#                 (('0982434333',), 17),
#                 (('societarias',), 16),
#                 (('azogues',), 15),
#                 (('954355704',), 14),
#                 (('globalcaja',), 12),
#                 (('viepi',), 12),
#                 (('expoplaza',), 11),
#                 (('09d09',), 11),
#                 (('interlab',), 10),
#                 (('13d02',), 10),
#                 (('23d01',), 10),
#                 (('geosalud',), 10),
#                 (('09d02',), 10),
#                 (('3433personasrecuperadas',), 10),
#                 (('zaruma',), 9),
#                 (('ecuadorguayaquil',), 9),
#                 (('amarillonaranja',), 9),
#                 (('guachapala',), 9),
#                 (('0939733371',), 8),
#                 (('23d02',), 8),
#                 (('recuerdelo',), 8),
#                 (('cbmq',), 7),
#                 (('pillaro',), 7),
#                 (('macara',), 7)],
#  ('mx', 'es'): [(('coahuila',), 1268),
#                 (('mexiquenses',), 1229),
#                 (('slp',), 800),
#                 (('poblanos',), 744),
#                 (('panteones',), 722),
#                 (('aguascalientes',), 550),
#                 (('toluca',), 520),
#                 (('cuernavaca',), 517),
#                 (('campeche',), 448),
#                 (('colima',), 431),
#                 (('iztapalapa',), 379),
#                 (('murat',), 335),
#                 (('alcocer',), 328),
#                 (('chingo',), 280),
#                 (('pulsopoliticodeoaxaca',), 269),
#                 (('pachuca',), 263),
#                 (('infonavit',), 246),
#                 (('nayarit',), 244),
#                 (('ssp',), 243),
#                 (('matamoros',), 229),
#                 (('inegi',), 226),
#                 (('monclova',), 215),
#                 (('mazatlan',), 214),
#                 (('laredo',), 207),
#                 (('xalapa',), 202),
#                 (('ssm',), 196),
#                 (('mixteca',), 195),
#                 (('naucalpan',), 190),
#                 (('neza',), 186),
#                 (('oaxaqueña',), 185)],
#  ('pe', 'es'): [(('maguiña',), 173),
#                 (('ancash',), 153),
#                 (('sjl',), 75),
#                 (('yahaira',), 74),
#                 (('huaraz',), 71),
#                 (('martos',), 68),
#                 (('tarija',), 67),
#                 (('surquillo',), 67),
#                 (('almenara',), 64),
#                 (('limaperu',), 57),
#                 (('yoshiyama',), 56),
#                 (('chorrillos',), 53),
#                 (('fpf',), 51),
#                 (('oruro',), 50),
#                 (('chimbote',), 50),
#                 (('pucp',), 49),
#                 (('huanuco',), 47),
#                 (('copello',), 46),
#                 (('pold',), 43),
#                 (('smp',), 42),
#                 (('plasencia',), 42),
#                 (('31190',), 42),
#                 (('huancayo',), 39),
#                 (('sullana',), 37),
#                 ((':_emoji_not_identified_U279B_:',), 36),
#                 (('mininter',), 33),
#                 (('chuquisaca',), 33),
#                 (('kouri',), 33),
#                 (('larco',), 33),
#                 (('negreiros',), 32)]}

# %%
plot_bar_matrix(counts, num_top_words = 30, num_cols = 2)

# %% [markdown]
# ## II. Tweet queries from May 26, 2020 to June 26, 2020:

# %%
# !python3 coveet.py query -g ar co ec mx pe -l es -d 2020-05-26 2020-06-26
# Out:
# Namespace(all=False, date=[datetime.datetime(2020, 5, 26, 0, 0), datetime.datetime(2020, 6, 26, 0, 0)], func=<function handle_query at 0x7f2a7461d4c0>, geo=['ar', 'co', 'ec', 'mx', 'pe'], lang=['es'], search=None)
# wrote df to dhcovid_2020-5-26_2020-6-26_es_ar_co_ec_mx_pe.csv 🎉

# %%
df = pd.read_csv('dhcovid_2020-5-26_2020-6-26_es_ar_co_ec_mx_pe.csv', index_col=0)

# %%
# !python3 coveet.py tidy -file dhcovid_2020-5-26_2020-6-26_es_ar_co_ec_mx_pe.csv -stopwords ../stopwords/stopwords_es.txt ../stopwords/stopwords_hashtags.txt
# Out:
# Namespace(file='dhcovid_2020-5-26_2020-6-26_es_ar_co_ec_mx_pe.csv', func=<function handle_tidy at 0x7f31923245e0>, lemmatize=False, search=None, stopwords=['../stopwords/stopwords_es.txt', '../stopwords/stopwords_hashtags.txt'])
# wrote tidied df to dhcovid_2020-5-26_2020-6-26_es_ar_co_ec_mx_pe_stopworded.csv 🎉

# %%
df = pd.read_csv('dhcovid_2020-5-26_2020-6-26_es_ar_co_ec_mx_pe_stopworded.csv', index_col=0)

# %%
df['date'] = pd.to_datetime(df['date'])
df['text'] = df['text'].str.split()
df['hashtags'] = df['hashtags'].str.split()

# %% [markdown]
# ### Top 30 words

# %%
top_n = 30  # top 30 words
n_gram = 1  # ask for word frequency (i.e. an n-gram where n=1)
col_name = 'text'  # set to either 'text' or 'hashtags'
df_text = df.dropna(subset=[col_name]) 
counts = {(g, l): Counter(count_ngrams(t, n_gram, consecutive=False)).most_common(top_n)
          for (g, l), t in df_text.groupby(["geo", "lang"])[col_name]}

# %%
pprint(counts)
# Out:
# {('ar', 'es'): [(('casos',), 8989),
#                 (('nuevos',), 3603),
#                 (('positivo',), 3597),
#                 (('hoy',), 3340),
#                 (('coronavirus',), 3166),
#                 (('caso',), 3135),
#                 (('pandemia',), 3095),
#                 (('salud',), 2766),
#                 (('personas',), 2728),
#                 (('pais',), 2558),
#                 (('cuarentena',), 2521),
#                 (('argentina',), 2504),
#                 (('covid',), 2481),
#                 (('gente',), 2205),
#                 (('positivos',), 2176),
#                 (('nuevo',), 1803),
#                 (('situacion',), 1760),
#                 (('muertes',), 1730),
#                 (('pacientes',), 1704),
#                 (('provincia',), 1646),
#                 (('virus',), 1541),
#                 (('contagios',), 1471),
#                 (('ciudad',), 1441),
#                 (('gobierno',), 1428),
#                 (('mundo',), 1392),
#                 (('test',), 1369),
#                 (('muertos',), 1297),
#                 (('años',), 1266),
#                 (('hospital',), 1250),
#                 (('total',), 1241)],
#  ('co', 'es'): [(('casos',), 18546),
#                 (('salud',), 8534),
#                 (('pandemia',), 8260),
#                 (('nuevos',), 8102),
#                 (('colombia',), 7764),
#                 (('hoy',), 7643),
#                 (('personas',), 6241),
#                 (('medidas',), 5926),
#                 (('pais',), 5613),
#                 (('junio',), 5230),
#                 (('pruebas',), 5198),
#                 (('coronavirus',), 5042),
#                 (('contagios',), 4597),
#                 (('pacientes',), 4590),
#                 (('gobierno',), 4332),
#                 (('muertes',), 4243),
#                 (('contagio',), 4013),
#                 (('fallecidos',), 3964),
#                 (('virus',), 3571),
#                 (('crisis',), 3431),
#                 (('traves',), 3419),
#                 (('panama',), 3345),
#                 (('evitar',), 3268),
#                 (('gente',), 3085),
#                 (('recuperados',), 3067),
#                 (('nacional',), 3034),
#                 (('mundo',), 3026),
#                 (('positivos',), 3012),
#                 (('atencion',), 2966),
#                 (('total',), 2965)],
#  ('ec', 'es'): [(('casos',), 3119),
#                 (('pruebas',), 3084),
#                 (('salud',), 2489),
#                 (('pandemia',), 2275),
#                 (('ecuador',), 1923),
#                 (('personas',), 1891),
#                 (('junio',), 1632),
#                 (('hoy',), 1366),
#                 (('medidas',), 1345),
#                 (('pacientes',), 1307),
#                 (('pais',), 1225),
#                 (('quito',), 1183),
#                 (('atencion',), 1182),
#                 (('emergencia',), 1175),
#                 (('evitar',), 1116),
#                 (('coronavirus',), 1051),
#                 (('fallecidos',), 995),
#                 (('detalles',), 993),
#                 (('contagios',), 964),
#                 (('virus',), 952),
#                 (('vida',), 924),
#                 (('sanitaria',), 915),
#                 (('contagio',), 910),
#                 (('mundo',), 828),
#                 (('prevenir',), 815),
#                 (('nacional',), 794),
#                 (('propagacion',), 793),
#                 (('positivos',), 791),
#                 (('traves',), 789),
#                 (('confirmados',), 784)],
#  ('mx', 'es'): [(('casos',), 39890),
#                 (('mexico',), 28475),
#                 (('pandemia',), 21168),
#                 (('contagios',), 18825),
#                 (('salud',), 17576),
#                 (('muertes',), 13151),
#                 (('personas',), 12097),
#                 (('hoy',), 11265),
#                 (('gobierno',), 11029),
#                 (('medidas',), 10575),
#                 (('coronavirus',), 10459),
#                 (('nuevos',), 10221),
#                 (('junio',), 9599),
#                 (('defunciones',), 9453),
#                 (('pacientes',), 9270),
#                 (('confirmados',), 9057),
#                 (('positivo',), 8209),
#                 (('positivos',), 7796),
#                 (('crisis',), 7716),
#                 (('pais',), 7687),
#                 (('estado',), 7198),
#                 (('muertos',), 6727),
#                 (('nueva',), 6546),
#                 (('riesgo',), 6251),
#                 (('contingencia',), 6145),
#                 (('contagio',), 6107),
#                 (('casa',), 6065),
#                 (('pruebas',), 5815),
#                 (('horas',), 5773),
#                 (('hospital',), 5737)],
#  ('pe', 'es'): [(('peru',), 3956),
#                 (('coronavirus',), 3309),
#                 (('casos',), 3069),
#                 (('salud',), 2539),
#                 (('pacientes',), 2199),
#                 (('pandemia',), 1951),
#                 (('hoy',), 1750),
#                 (('personas',), 1563),
#                 (('pruebas',), 1543),
#                 (('pais',), 1417),
#                 (('gobierno',), 1363),
#                 (('fallecidos',), 1362),
#                 (('traves',), 1221),
#                 (('cuarentena',), 1194),
#                 (('hospital',), 1166),
#                 (('junio',), 1134),
#                 (('emergencia',), 1032),
#                 (('positivo',), 1004),
#                 (('mundo',), 1001),
#                 (('estado',), 939),
#                 (('contagios',), 920),
#                 (('lima',), 896),
#                 (('atencion',), 862),
#                 (('nuevo',), 774),
#                 (('clinicas',), 770),
#                 (('frente',), 760),
#                 (('video',), 756),
#                 (('lucha',), 744),
#                 (('crisis',), 743),
#                 (('nuevos',), 733)]}

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 40, 40  # setting figure size
plt.rcParams.update({'font.size': 22})  # setting font size

# %%
plot_bar_matrix(counts, num_top_words = top_n, num_cols = 2)

# %% [markdown]
# ### Top hashtags

# %%
top_n = 30  # top 30 words
n_gram = 1  # ask for word frequency (i.e. an n-gram where n=1)
col_name = 'hashtags'  # set to either 'text' or 'hashtags'
df_text = df.dropna(subset=[col_name])
counts = {(g, l): Counter(count_ngrams(t, n_gram, consecutive=False)).most_common(top_n)
          for (g, l), t in df_text.groupby(["geo", "lang"])[col_name]}

# %%
pprint(counts)
# Out:
# {('ar', 'es'): [(('#quedateencasa',), 692),
#                 (('#cuarentena',), 513),
#                 (('#argentina',), 509),
#                 (('#ahora',), 438),
#                 (('#pandemia',), 421),
#                 (('#laplata',), 404),
#                 (('#coronavirusargentina',), 323),
#                 (('#noscuidamosentretodos',), 312),
#                 (('#quedateentucasa',), 281),
#                 (('#afp',), 238),
#                 (('#salud',), 236),
#                 (('#ahoramontevideo',), 209),
#                 (('#uruguaydecide',), 191),
#                 (('#yomequedoencasa',), 188),
#                 (('#covid19uruguay',), 184),
#                 (('#noticias',), 174),
#                 (('#elecciones2020',), 155),
#                 (('#cuidarteescuidarnos',), 154),
#                 (('#uruguay',), 153),
#                 (('#tuvoto',), 145),
#                 (('#rosario',), 136),
#                 (('#cordoba',), 129),
#                 (('#brasil',), 128),
#                 (('#raffointendente',), 127),
#                 (('#argentinaunida',), 125),
#                 (('#buenosaires',), 123),
#                 (('#santafe',), 123),
#                 (('#covid19argentina',), 117),
#                 (('#coronavirusenargentina',), 113),
#                 (('#berisso',), 106)],
#  ('co', 'es'): [(('#quedateencasa',), 2300),
#                 (('#disciplinaparavolver',), 1927),
#                 (('#atencion',), 1357),
#                 (('#colombia',), 1222),
#                 (('#noticiastvn',), 1073),
#                 (('#prevencionyaccion',), 1071),
#                 (('#ecuador',), 1030),
#                 (('#diasiniva',), 925),
#                 (('#panama',), 860),
#                 (('#evitaelcoronavirus',), 844),
#                 (('#reportecovid19',), 779),
#                 (('#salud',), 740),
#                 (('#3pasosdevida',), 654),
#                 (('#envivo',), 590),
#                 (('#somosunosomostodos',), 552),
#                 (('#cordoba',), 537),
#                 (('#quito',), 504),
#                 (('#pandemia',), 439),
#                 (('#venezuela',), 437),
#                 (('#fanb',), 420),
#                 (('#aestahora',), 417),
#                 (('#noticias',), 417),
#                 (('#bogota',), 407),
#                 (('#cuarentena',), 404),
#                 (('#ultimahora',), 391),
#                 (('#yomequedoencasa',), 390),
#                 (('#nacionales',), 372),
#                 (('#mundo',), 371),
#                 (('#monteria',), 365),
#                 (('#dependedetodos',), 364)],
#  ('ec', 'es'): [(('#disciplinaparavolver',), 1917),
#                 (('#ecuador',), 1787),
#                 (('#3pasosdevida',), 652),
#                 (('#atencion',), 597),
#                 (('#quito',), 581),
#                 (('#quedateencasa',), 498),
#                 (('#guayaquil',), 358),
#                 (('#conmedidassalvamosvidas',), 357),
#                 (('#cuenca',), 264),
#                 (('#aecuadorlosacamostodos',), 246),
#                 (('#noticias',), 236),
#                 (('#urgente',), 228),
#                 (('#covid19ec',), 220),
#                 (('#quitosaleseguro',), 204),
#                 (('#activadosporlasalud',), 201),
#                 (('#mundo',), 185),
#                 (('#emergenciasanitaria',), 171),
#                 (('#coronavirusenecuador',), 169),
#                 (('#manabi',), 162),
#                 (('#semaforoamarilloenquito',), 143),
#                 (('#somosunosomostodos',), 140),
#                 (('#salud',), 128),
#                 (('#coronavirusecuador',), 120),
#                 (('#distanciasegura',), 116),
#                 (('#loja',), 115),
#                 (('#guayas',), 114),
#                 (('#pandemia',), 111),
#                 (('#actualizacion',), 111),
#                 (('#noscuidamostodos',), 107),
#                 (('#azuay',), 99)],
#  ('mx', 'es'): [(('#quedateencasa',), 10300),
#                 (('#covid19mx',), 10142),
#                 (('#mexico',), 5552),
#                 (('#enterate',), 4467),
#                 (('#edomexensemafororojo',), 4172),
#                 (('#oaxaca',), 3559),
#                 (('#ultimahora',), 2995),
#                 (('#nacional',), 2732),
#                 (('#puebla',), 2505),
#                 (('#amlomientenohaytrabajo',), 2249),
#                 (('#edomex',), 2139),
#                 (('#salud',), 1863),
#                 (('#noticias',), 1800),
#                 (('#cdmx',), 1772),
#                 (('#nuevanormalidad',), 1539),
#                 (('#pandemia',), 1376),
#                 (('#internacional',), 1306),
#                 (('#veracruz',), 1293),
#                 (('#sanadistancia',), 1208),
#                 (('#slp',), 1180),
#                 (('#unidoscontralacrisis',), 1125),
#                 (('#yomequedoencasa',), 1100),
#                 (('#mundo',), 1097),
#                 (('#envivo',), 1069),
#                 (('#ir',), 1065),
#                 (('#video',), 1015),
#                 (('#unamosalpueblo',), 997),
#                 (('#coahuila',), 971),
#                 (('#amlonoapoyaalpueblo',), 951),
#                 (('#exigimosinsumosdecalidad',), 917)],
#  ('pe', 'es'): [(('#quedateencasa',), 796),
#                 (('#peru',), 601),
#                 (('#bolivia',), 590),
#                 (('#panamericananoticias',), 426),
#                 (('#ultimo',), 354),
#                 (('#yomequedoencasa',), 339),
#                 (('#loultimo',), 324),
#                 (('#fmbolivia',), 274),
#                 (('#cuarentena',), 252),
#                 (('#coronavirusenperu',), 251),
#                 (('#24horas',), 234),
#                 (('#mundo',), 221),
#                 (('#p7informa',), 201),
#                 (('#arequipa',), 200),
#                 (('#atvnoticiasmatinal',), 198),
#                 (('#envivo',), 175),
#                 (('#atencion',), 167),
#                 (('#urgente',), 161),
#                 (('#pandemia',), 156),
#                 (('#video',), 153),
#                 (('#bdp',), 148),
#                 (('#salud',), 140),
#                 (('#noticias',), 135),
#                 (('#coronavirusbo',), 134),
#                 (('#estadodeemergencia',), 134),
#                 (('#lapaz',), 122),
#                 (('#peruestaennuestrasmanos',), 112),
#                 (('#ahora',), 110),
#                 (('#covid19peru',), 101),
#                 (('#anonymous',), 101)]}

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 40, 40  # setting figure size
plt.rcParams.update({'font.size': 22})  # setting font size

# %%
plot_bar_matrix(counts, num_top_words = top_n, num_cols = 2)

# %% [markdown]
# ### Top 20 unique words, and their visualizations

# %%
col_name = "text"

# %%
df = df.dropna(subset=[col_name])

# %%
grouping = df.groupby(["geo", "lang"])[col_name]
vocab_dic = uniq_vocab_by_group(grouping)  # unique vocab dictionary 
df[col_name] = df.apply(lambda x : set(x[col_name]) & vocab_dic[(x['geo'], x['lang'])],
                        result_type='reduce', axis=1)  # filtering tweets by that dic

# %%
counts = {k: Counter(count_ngrams(t, n_gram, consecutive=False)).most_common(top_n) for k, t in grouping}

# %%
pprint(counts)
# Out:
# {('ar', 'es'): [(('bonaerense',), 192),
#                 (('catamarca',), 138),
#                 (('lanus',), 105),
#                 (('telefe',), 96),
#                 (('traslasierra',), 82),
#                 (('pba',), 81),
#                 (('peronismo',), 77),
#                 (('bonaerenses',), 74),
#                 (('sinae',), 73),
#                 (('pibe',), 72),
#                 (('asse',), 68),
#                 (('jujuy',), 67),
#                 (('berisso',), 67),
#                 (('inscribite',), 65),
#                 (('gualeguaychu',), 58),
#                 (('besona',), 55),
#                 (('boludo',), 54),
#                 (('ezeiza',), 54),
#                 (('chivilcoy',), 52),
#                 (('chajari',), 52),
#                 (('belgrano',), 51),
#                 (('lavandina',), 48),
#                 (('gesell',), 47),
#                 (('pehuajo',), 47),
#                 (('bsas',), 46),
#                 (('17415',), 46),
#                 (('creuso',), 45),
#                 (('18818',), 45),
#                 (('comodoro',), 45),
#                 (('livramento',), 43)],
#  ('co', 'es'): [(('boyaca',), 509),
#                 (('monteria',), 474),
#                 (('bucaramanga',), 324),
#                 (('veraguas',), 296),
#                 (('barrancabermeja',), 270),
#                 (('tunja',), 242),
#                 (('caldas',), 232),
#                 (('sincelejo',), 203),
#                 (('css',), 189),
#                 (('lorica',), 156),
#                 (('manizales',), 130),
#                 (('soacha',), 127),
#                 (('neiva',), 122),
#                 (('casanare',), 116),
#                 (('cocle',), 102),
#                 (('carepa',), 96),
#                 (('gorgas',), 93),
#                 (('cubrimiento',), 92),
#                 (('itagui',), 92),
#                 (('sogamoso',), 88),
#                 (('floridablanca',), 87),
#                 (('53063',), 86),
#                 (('arraijan',), 81),
#                 (('corferias',), 79),
#                 (('envigado',), 78),
#                 (('invima',), 76),
#                 (('iibt',), 73),
#                 (('metrolinea',), 72),
#                 (('gnbesvzla',), 71),
#                 (('bosa',), 64)],
#  ('ec', 'es'): [(('09d01',), 25),
#                 (('viepi',), 21),
#                 (('azogues',), 20),
#                 (('archidonense',), 19),
#                 (('observatoriocc@user',), 15),
#                 (('eluniverso',), 13),
#                 (('delcontagio',), 12),
#                 (('ecuadormachala',), 11),
#                 (('crnl',), 11),
#                 (('whataspp',), 10),
#                 (('cdla',), 9),
#                 (('7salud',), 8),
#                 (('ñuka',), 8),
#                 (('0982434333',), 8),
#                 (('saraguro',), 8),
#                 (('09d03',), 8),
#                 (('montecristi',), 8),
#                 (('hvcm',), 8),
#                 (('09d05',), 7),
#                 (('crsturi',), 7),
#                 (('stefanny',), 7),
#                 (('luzuriaga',), 7),
#                 (('educomunicacional',), 6),
#                 (('distrito09d08',), 6),
#                 (('yaguachi',), 6),
#                 (('ventaseducontinua@user',), 6),
#                 (('20192023',), 6),
#                 (('pañi',), 6),
#                 (('socializados',), 5),
#                 (('flagrantes',), 5)],
#  ('mx', 'es'): [(('edomex',), 1453),
#                 (('tabasco',), 1124),
#                 (('coahuila',), 848),
#                 (('guanajuato',), 776),
#                 (('slp',), 630),
#                 (('sesa',), 581),
#                 (('despensas',), 475),
#                 (('aguascalientes',), 474),
#                 (('campeche',), 370),
#                 (('colima',), 363),
#                 (('sedena',), 254),
#                 (('cuernavaca',), 254),
#                 (('cereso',), 232),
#                 (('tuxtla',), 208),
#                 (('panteon',), 205),
#                 (('vallarta',), 203),
#                 (('insabi',), 200),
#                 (('cholula',), 195),
#                 (('tehuacan',), 195),
#                 (('ecatepec',), 192),
#                 (('covidindustrial',), 189),
#                 (('mañanera',), 187),
#                 (('951',), 186),
#                 (('huejotzingo',), 183),
#                 (('bcs',), 178),
#                 (('murat',), 169),
#                 (('ssm',), 169),
#                 (('hidalguense',), 167),
#                 (('saltillo',), 163),
#                 (('ssp',), 160)],
#  ('pe', 'es'): [(('ancash',), 108),
#                 (('ucayali',), 79),
#                 (('rebagliati',), 59),
#                 (('inmovilizacion',), 58),
#                 (('puno',), 54),
#                 (('inpe',), 54),
#                 (('huaraz',), 53),
#                 (('chiclayo',), 51),
#                 (('cmp',), 51),
#                 (('maguiña',), 48),
#                 (('tarija',), 46),
#                 (('minedu',), 42),
#                 (('revilla',), 40),
#                 (('chuquisaca',), 37),
#                 (('gastello',), 35),
#                 (('chorrillos',), 33),
#                 (('bazalar',), 32),
#                 (('huanuco',), 32),
#                 (('gastelo',), 32),
#                 (('tayta',), 32),
#                 (('quispe',), 30),
#                 (('sinadef',), 29),
#                 (('pucallpa',), 29),
#                 (('barsallo',), 28),
#                 (('irivarren',), 27),
#                 (('huacho',), 27),
#                 (('cañete',), 26),
#                 (('indecopi',), 26),
#                 (('elperu',), 25),
#                 (('4099',), 25)]}

# %%
plot_bar_matrix(counts, num_top_words = 30, num_cols = 2)

# %% [markdown]
# ## III. Tweet queries from June 27, 2020 to July 27, 2020:

# %%
# !python3 coveet.py query -g ar co ec mx pe -l es -d 2020-06-27 2020-07-27
# Out:
# Namespace(all=False, date=[datetime.datetime(2020, 6, 27, 0, 0), datetime.datetime(2020, 7, 27, 0, 0)], func=<function handle_query at 0x7f27888294c0>, geo=['ar', 'co', 'ec', 'mx', 'pe'], lang=['es'], search=None)
# wrote df to dhcovid_2020-6-27_2020-7-27_es_ar_co_ec_mx_pe.csv 🎉

# %%
df = pd.read_csv('dhcovid_2020-6-27_2020-7-27_es_ar_co_ec_mx_pe.csv', index_col=0)

# %%
# !python3 coveet.py tidy -file dhcovid_2020-6-27_2020-7-27_es_ar_co_ec_mx_pe.csv -stopwords ../stopwords/stopwords_es.txt ../stopwords/stopwords_hashtags.txt
# Out:
# Namespace(file='dhcovid_2020-6-27_2020-7-27_es_ar_co_ec_mx_pe.csv', func=<function handle_tidy at 0x7fba788255e0>, lemmatize=False, search=None, stopwords=['../stopwords/stopwords_es.txt', '../stopwords/stopwords_hashtags.txt'])
# wrote tidied df to dhcovid_2020-6-27_2020-7-27_es_ar_co_ec_mx_pe_stopworded.csv 🎉

# %%
df = pd.read_csv('dhcovid_2020-6-27_2020-7-27_es_ar_co_ec_mx_pe_stopworded.csv', index_col=0) # run this file

# %%
df['date'] = pd.to_datetime(df['date'])
df['text'] = df['text'].str.split()
df['hashtags'] = df['hashtags'].str.split()

# %% [markdown]
# ### Top 30 Words

# %%
top_n = 30  # top 30 words
n_gram = 1  # ask for word frequency (i.e. an n-gram where n=1)
col_name = 'text'  # set to either 'text' or 'hashtags'
df_text = df.dropna(subset=[col_name])
counts = {(g, l): Counter(count_ngrams(t, n_gram, consecutive=False)).most_common(top_n)
          for (g, l), t in df_text.groupby(["geo", "lang"])[col_name]}

# %%
pprint(counts)
# Out:
# {('ar', 'es'): [(('casos',), 11206),
#                 (('positivo',), 5130),
#                 (('nuevos',), 5118),
#                 (('hoy',), 4034),
#                 (('covid',), 3894),
#                 (('coronavirus',), 3720),
#                 (('caso',), 3314),
#                 (('pandemia',), 3241),
#                 (('salud',), 3158),
#                 (('positivos',), 3069),
#                 (('argentina',), 2852),
#                 (('personas',), 2842),
#                 (('pais',), 2504),
#                 (('gente',), 2353),
#                 (('cuarentena',), 2196),
#                 (('vacuna',), 2168),
#                 (('nuevo',), 2041),
#                 (('muertes',), 1990),
#                 (('contagios',), 1971),
#                 (('provincia',), 1954),
#                 (('pacientes',), 1868),
#                 (('situacion',), 1737),
#                 (('años',), 1685),
#                 (('virus',), 1600),
#                 (('bolsonaro',), 1598),
#                 (('ciudad',), 1584),
#                 (('total',), 1548),
#                 (('julio',), 1460),
#                 (('gobierno',), 1421),
#                 (('mundo',), 1417)],
#  ('co', 'es'): [(('casos',), 22560),
#                 (('salud',), 10723),
#                 (('nuevos',), 9789),
#                 (('hoy',), 9378),
#                 (('pandemia',), 8943),
#                 (('personas',), 7937),
#                 (('colombia',), 7901),
#                 (('pruebas',), 7227),
#                 (('pacientes',), 6569),
#                 (('medidas',), 6506),
#                 (('julio',), 6478),
#                 (('contagios',), 6474),
#                 (('pais',), 6234),
#                 (('positivo',), 5855),
#                 (('coronavirus',), 5654),
#                 (('fallecidos',), 5338),
#                 (('contagio',), 4985),
#                 (('positivos',), 4540),
#                 (('virus',), 4499),
#                 (('vacuna',), 4475),
#                 (('atencion',), 4405),
#                 (('total',), 4348),
#                 (('prueba',), 4311),
#                 (('gobierno',), 4241),
#                 (('muertes',), 4173),
#                 (('traves',), 3974),
#                 (('covid',), 3865),
#                 (('nacional',), 3795),
#                 (('gente',), 3650),
#                 (('prevencion',), 3543)],
#  ('ec', 'es'): [(('casos',), 3863),
#                 (('pruebas',), 2671),
#                 (('salud',), 2611),
#                 (('quito',), 2503),
#                 (('pandemia',), 2112),
#                 (('personas',), 2038),
#                 (('ecuador',), 1808),
#                 (('julio',), 1725),
#                 (('contagios',), 1670),
#                 (('pacientes',), 1473),
#                 (('hoy',), 1461),
#                 (('atencion',), 1327),
#                 (('detalles',), 1294),
#                 (('medidas',), 1247),
#                 (('pais',), 1135),
#                 (('nacional',), 1090),
#                 (('contagio',), 1052),
#                 (('coronavirus',), 1040),
#                 (('virus',), 1022),
#                 (('vacuna',), 1018),
#                 (('guayaquil',), 985),
#                 (('emergencia',), 925),
#                 (('municipio',), 909),
#                 (('fallecidos',), 893),
#                 (('confirmados',), 882),
#                 (('deteccion',), 875),
#                 (('evitar',), 847),
#                 (('positivos',), 839),
#                 (('positivo',), 834),
#                 (('mundo',), 833)],
#  ('mx', 'es'): [(('casos',), 38999),
#                 (('mexico',), 26802),
#                 (('contagios',), 19649),
#                 (('pandemia',), 19438),
#                 (('salud',), 17598),
#                 (('muertes',), 13103),
#                 (('personas',), 12275),
#                 (('hoy',), 10844),
#                 (('nuevos',), 10359),
#                 (('medidas',), 10356),
#                 (('coronavirus',), 10021),
#                 (('positivo',), 9701),
#                 (('vacuna',), 9063),
#                 (('julio',), 8912),
#                 (('pacientes',), 8778),
#                 (('positivos',), 8755),
#                 (('covid',), 8589),
#                 (('defunciones',), 8304),
#                 (('gobierno',), 7901),
#                 (('confirmados',), 7576),
#                 (('estado',), 7139),
#                 (('prueba',), 6917),
#                 (('pais',), 6856),
#                 (('muertos',), 6115),
#                 (('nuevo',), 6108),
#                 (('pruebas',), 6065),
#                 (('casa',), 6047),
#                 (('hospital',), 5944),
#                 (('cubrebocas',), 5930),
#                 (('horas',), 5866)],
#  ('pe', 'es'): [(('casos',), 3458),
#                 (('peru',), 3060),
#                 (('coronavirus',), 2924),
#                 (('salud',), 2571),
#                 (('pacientes',), 2407),
#                 (('pandemia',), 1858),
#                 (('personas',), 1631),
#                 (('fallecidos',), 1612),
#                 (('hoy',), 1537),
#                 (('positivo',), 1524),
#                 (('vacuna',), 1429),
#                 (('julio',), 1389),
#                 (('traves',), 1327),
#                 (('hospital',), 1321),
#                 (('gobierno',), 1290),
#                 (('contagios',), 1280),
#                 (('cuarentena',), 1184),
#                 (('pruebas',), 1178),
#                 (('pais',), 1139),
#                 (('atencion',), 1026),
#                 (('nuevos',), 979),
#                 (('arequipa',), 908),
#                 (('mundo',), 882),
#                 (('minsa',), 874),
#                 (('lima',), 872),
#                 (('presidente',), 821),
#                 (('prueba',), 819),
#                 (('estado',), 818),
#                 (('oxigeno',), 814),
#                 (('covid',), 798)]}

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 40, 40  # setting figure size
plt.rcParams.update({'font.size': 22})  # setting font size

# %%
plot_bar_matrix(counts, num_top_words = top_n, num_cols = 2)

# %% [markdown]
# ### Top 30 Hashtags

# %%
top_n = 30  # top 30 words
n_gram = 1  # ask for word frequency (i.e. an n-gram where n=1)
col_name = 'hashtags'  # set to either 'text' or 'hashtags'
df_text = df.dropna(subset=[col_name])
counts = {(g, l): Counter(count_ngrams(t, n_gram, consecutive=False)).most_common(top_n)
          for (g, l), t in df_text.groupby(["geo", "lang"])[col_name]}

# %%
pprint(counts)
# Out:
# {('ar', 'es'): [(('#quedateencasa',), 671),
#                 (('#ahora',), 562),
#                 (('#argentina',), 502),
#                 (('#pandemia',), 425),
#                 (('#cuarentena',), 387),
#                 (('#quedateentucasa',), 351),
#                 (('#noscuidamosentretodos',), 321),
#                 (('#laplata',), 299),
#                 (('#coronavirusargentina',), 296),
#                 (('#salud',), 270),
#                 (('#noticias',), 234),
#                 (('#ahoramontevideo',), 233),
#                 (('#uruguaydecide',), 215),
#                 (('#rosario',), 210),
#                 (('#afp',), 210),
#                 (('#elecciones2020',), 181),
#                 (('#cuidarteescuidarnos',), 175),
#                 (('#tuvoto',), 166),
#                 (('#buenosaires',), 165),
#                 (('#santafe',), 164),
#                 (('#cordoba',), 153),
#                 (('#covid19uruguay',), 151),
#                 (('#quilmes',), 138),
#                 (('#uruguay',), 135),
#                 (('#raffointendente',), 134),
#                 (('#actualizacion',), 126),
#                 (('#argentinaunida',), 123),
#                 (('#urgente',), 120),
#                 (('#brasil',), 118),
#                 (('#coronavirusenargentina',), 111)],
#  ('co', 'es'): [(('#quedateencasa',), 2364),
#                 (('#atencion',), 1872),
#                 (('#colombia',), 1557),
#                 (('#noterelajes',), 1556),
#                 (('#prevencionyaccion',), 1240),
#                 (('#ecuador',), 1153),
#                 (('#salud',), 1055),
#                 (('#reportecovid19',), 1007),
#                 (('#panama',), 965),
#                 (('#cordoba',), 886),
#                 (('#fanb',), 851),
#                 (('#quito',), 837),
#                 (('#quitoconprueba',), 830),
#                 (('#noticiastvn',), 823),
#                 (('#nobajemoslaguardia',), 720),
#                 (('#noticias',), 655),
#                 (('#venezuela',), 628),
#                 (('#mundo',), 622),
#                 (('#monteria',), 612),
#                 (('#envivo',), 606),
#                 (('#pandemia',), 598),
#                 (('#yomequedoencasa',), 597),
#                 (('#evitaelcoronavirus',), 570),
#                 (('#quitocontraelcovid19',), 569),
#                 (('#somosunosomostodos',), 557),
#                 (('#bogota',), 527),
#                 (('#ultimahora',), 508),
#                 (('#nacionales',), 493),
#                 (('#aestahora',), 477),
#                 (('#treporta',), 436)],
#  ('ec', 'es'): [(('#ecuador',), 1938),
#                 (('#noterelajes',), 1553),
#                 (('#quito',), 997),
#                 (('#atencion',), 915),
#                 (('#quitoconprueba',), 830),
#                 (('#quitocontraelcovid19',), 574),
#                 (('#guayaquil',), 404),
#                 (('#quedateencasa',), 393),
#                 (('#cuenca',), 297),
#                 (('#mundo',), 274),
#                 (('#noticias',), 250),
#                 (('#disciplinaparavolver',), 242),
#                 (('#urgente',), 215),
#                 (('#loja',), 205),
#                 (('#arcsatecuida',), 188),
#                 (('#covid19ec',), 180),
#                 (('#manabi',), 170),
#                 (('#ktc',), 165),
#                 (('#internacional',), 157),
#                 (('#quitosaleseguro',), 129),
#                 (('#nacional',), 126),
#                 (('#nacionales',), 125),
#                 (('#coenacional',), 121),
#                 (('#noscuidamosentretodos',), 120),
#                 (('#pandemia',), 119),
#                 (('#salud',), 119),
#                 (('#china',), 119),
#                 (('#pichincha',), 117),
#                 (('#aecuadorlosacamostodos',), 111),
#                 (('#azuay',), 105)],
#  ('mx', 'es'): [(('#covid19mx',), 6714),
#                 (('#mexico',), 5515),
#                 (('#quedateencasa',), 5240),
#                 (('#enterate',), 4833),
#                 (('#oaxaca',), 3266),
#                 (('#ultimahora',), 2963),
#                 (('#nacional',), 2779),
#                 (('#puebla',), 2395),
#                 (('#salud',), 2233),
#                 (('#edomex',), 1928),
#                 (('#noticias',), 1926),
#                 (('#cdmx',), 1878),
#                 (('#regresoseguroedomex',), 1815),
#                 (('#pandemia',), 1803),
#                 (('#veracruz',), 1712),
#                 (('#internacional',), 1582),
#                 (('#mundo',), 1287),
#                 (('#slp',), 1269),
#                 (('#sanadistancia',), 1175),
#                 (('#nuevanormalidad',), 1171),
#                 (('#video',), 1096),
#                 (('#ir',), 1053),
#                 (('#tamaulipas',), 1040),
#                 (('#coahuila',), 964),
#                 (('#local',), 941),
#                 (('#tlaxcala',), 930),
#                 (('#zacatecas',), 787),
#                 (('#envivo',), 770),
#                 (('#tabasco',), 754),
#                 (('#cuidemostodosdetodos',), 696)],
#  ('pe', 'es'): [(('#bolivia',), 642),
#                 (('#peru',), 547),
#                 (('#arequipa',), 417),
#                 (('#ultimo',), 400),
#                 (('#loultimo',), 387),
#                 (('#mundo',), 366),
#                 (('#fmbolivia',), 341),
#                 (('#panamericananoticias',), 339),
#                 (('#primeromisalud',), 327),
#                 (('#p7informa',), 294),
#                 (('#envivo',), 263),
#                 (('#lapaz',), 195),
#                 (('#atvnoticiasedicionmatinal',), 191),
#                 (('#atencion',), 181),
#                 (('#pandemia',), 175),
#                 (('#ahora',), 172),
#                 (('#noticias',), 165),
#                 (('#coronavirusbo',), 151),
#                 (('#video',), 150),
#                 (('#urgente',), 140),
#                 (('#cuarentena',), 132),
#                 (('#coronavirusenperu',), 128),
#                 (('#salud',), 123),
#                 (('#yomequedoencasa',), 118),
#                 (('#quedateencasa',), 117),
#                 (('#encontacto',), 105),
#                 (('#peruestaennuestrasmanos',), 102),
#                 (('#dia107',), 88),
#                 (('#coronavirusfacts',), 87),
#                 (('#opinion',), 84)]}

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 40, 40  # setting figure size
plt.rcParams.update({'font.size': 22})  # setting font size

# %%
plot_bar_matrix(counts, num_top_words = top_n, num_cols = 2)

# %% [markdown]
# ## Unique Top Words

# %%
col_name = "text"

# %%
df = df.dropna(subset=[col_name])

# %%
grouping = df.groupby(["geo", "lang"])[col_name]
vocab_dic = uniq_vocab_by_group(grouping)  # unique vocab dictionary 
df[col_name] = df.apply(lambda x : set(x[col_name]) & vocab_dic[(x['geo'], x['lang'])],
                        result_type='reduce', axis=1)  # filtering tweets by that dic

# %%
counts = {k: Counter(count_ngrams(t, n_gram, consecutive=False)).most_common(top_n) for k, t in grouping}

# %%
pprint(counts)
# Out:
# {('ar', 'es'): [(('lanus',), 141),
#                 (('olavarria',), 131),
#                 (('artigas',), 129),
#                 (('sinae',), 107),
#                 (('conurbano',), 97),
#                 (('zavalla',), 94),
#                 (('gualeguaychu',), 88),
#                 (('otamendi',), 87),
#                 (('paysandu',), 71),
#                 (('chilecito',), 65),
#                 (('pehuajo',), 64),
#                 (('bombal',), 57),
#                 (('berisso',), 56),
#                 (('conicet',), 53),
#                 (('santafesino',), 52),
#                 (('tacuarembo',), 51),
#                 (('francese',), 48),
#                 (('cañuelas',), 46),
#                 (('casilda',), 45),
#                 (('tandil',), 44),
#                 (('runners',), 42),
#                 (('villaguay',), 42),
#                 (('oncativo',), 41),
#                 (('casmu',), 40),
#                 (('chascomus',), 38),
#                 (('asse',), 38),
#                 (('ezeiza',), 38),
#                 (('castelli',), 37),
#                 (('henderson',), 36),
#                 (('rawson',), 36)],
#  ('co', 'es'): [(('casanare',), 318),
#                 (('duitama',), 244),
#                 (('sogamoso',), 237),
#                 (('risaralda',), 211),
#                 (('barrancabermeja',), 193),
#                 (('itagui',), 182),
#                 (('manizales',), 151),
#                 (('jamundi',), 139),
#                 (('rionegro',), 136),
#                 (('arauca',), 135),
#                 (('tulua',), 122),
#                 (('uraba',), 122),
#                 (('corferias',), 120),
#                 (('cerete',), 118),
#                 (('quindio',), 115),
#                 (('7945',), 106),
#                 (('tasajera',), 105),
#                 (('yopal',), 93),
#                 (('226373',), 91),
#                 (('adriani',), 90),
#                 (('7168',), 90),
#                 (('bogotanos',), 88),
#                 (('castillero',), 87),
#                 (('109505',), 84),
#                 (('soacha',), 82),
#                 (('maicao',), 81),
#                 (('7688',), 80),
#                 (('antioqueño',), 79),
#                 (('cubrimiento',), 77),
#                 (('piedecuesta',), 77)],
#  ('ec', 'es'): [(('viepi',), 28),
#                 (('15541',), 18),
#                 (('20192023',), 15),
#                 (('acb',), 12),
#                 (('hosteltur',), 12),
#                 (('archidonense',), 12),
#                 (('delincuencialahora',), 12),
#                 (('vienenx',), 12),
#                 (('avisales',), 12),
#                 (('miniestra',), 12),
#                 (('pepito',), 11),
#                 (('stefanny',), 11),
#                 (('900personasrecuperadas',), 11),
#                 (('asoguayas',), 11),
#                 (('vernaza',), 10),
#                 (('manabita',), 9),
#                 (('maxtvonline',), 9),
#                 (('altashospitalarias',), 8),
#                 (('alcivar',), 8),
#                 (('eerssa',), 8),
#                 (('lojano',), 8),
#                 (('huaquillas',), 7),
#                 (('cuencanos',), 7),
#                 (('educomunicacional',), 7),
#                 (('ñuka',), 7),
#                 (('suquilanda',), 7),
#                 (('velesaca',), 6),
#                 (('queiroz',), 6),
#                 (('5900personasrecuperadas',), 6),
#                 (('eft',), 6)],
#  ('mx', 'es'): [(('guanajuato',), 788),
#                 (('durango',), 685),
#                 (('slp',), 669),
#                 (('roo',), 559),
#                 (('mexiquenses',), 475),
#                 (('juchitan',), 431),
#                 (('campeche',), 340),
#                 (('inegi',), 320),
#                 (('dif',), 281),
#                 (('xalapa',), 274),
#                 (('oaxaqueños',), 257),
#                 (('nayarit',), 256),
#                 (('morelia',), 252),
#                 (('torreon',), 251),
#                 (('chilpancingo',), 221),
#                 (('conacyt',), 214),
#                 (('xochimilco',), 213),
#                 (('vallarta',), 197),
#                 (('cuernavaca',), 196),
#                 (('ssp',), 192),
#                 (('saltillo',), 188),
#                 (('culero',), 177),
#                 (('hidalguense',), 170),
#                 (('sedena',), 165),
#                 (('pulsopoliticodeoaxaca',), 162),
#                 (('coatzacoalcos',), 157),
#                 (('irapuato',), 150),
#                 (('cofepris',), 150),
#                 (('panteon',), 150),
#                 (('tehuantepec',), 149)],
#  ('pe', 'es'): [(('chiclayo',), 75),
#                 (('chimbote',), 73),
#                 (('sinadef',), 68),
#                 (('puno',), 67),
#                 (('moquegua',), 54),
#                 (('tarija',), 53),
#                 (('1917781799027',), 51),
#                 (('tacna',), 47),
#                 (('huaraz',), 47),
#                 (('cuyubamba',), 45),
#                 (('sjm',), 42),
#                 (('tayta',), 39),
#                 (('concambios',), 39),
#                 (('onp',), 35),
#                 (('rebagliati',), 35),
#                 (('vitarte',), 32),
#                 (('1917585898139',), 32),
#                 (('mazzeti',), 30),
#                 (('rimac',), 29),
#                 (('cachuca',), 29),
#                 (('apurimac',), 28),
#                 (('vacunandose',), 27),
#                 (('pasco',), 26),
#                 (('inpe',), 26),
#                 (('coed',), 26),
#                 (('juliaca',), 25),
#                 (('sjl',), 25),
#                 (('282365',), 25),
#                 (('señalalternativa',), 24),
#                 (('cantolao',), 24)]}

# %%
plot_bar_matrix(counts, num_top_words = 30, num_cols = 2)

# %% [markdown]
# 3. collectively (ar, ec, co, pe, mx) weekly corpus without stop words, top 10 words, top 5 hashtags, top 10 unique words, and their visualizations >>> SAT: Could Jerry run a script to get weekly results or do we need to do it by hand?
# 4. each country's (ar, ec, co, pe, mx individually) monthly and entire corpus without stop words, top 20 words, top 10 hashtags, top 20 unique words by location and by month (if time permits by week would be even better), and their visualizations  >> SAT: I am not sure that we need to do countries individually, the viz we have now offer already this results. And the location is tricky, do you want to locate all tweets?? This would have to be done through the database, and not with @Jerry's scripts.
# 5. overview with two months worth of information and see what that gives us >>> SAT: Do you mean to process the two months together? I think it would better to add another month, until July (which I added).
